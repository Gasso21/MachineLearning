# %% [markdown]
# # Heart Failure Prediction
#
# **Reference**
# - [Heart Fail:Analysis and Quick-prediction (NAYAN SAKHIYA)](https://www.kaggle.com/code/nayansakhiya/heart-fail-analysis-and-quick-prediction)

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ## Data Preprocessing

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('./heart_failure_clinical_records_dataset.csv')
#df = df.drop(df.loc[df['creatinine_phosphokinase']>3000].index, axis=0)
#df = pd.get_dummies(df)

float_columns = [x for x in df.columns if x not in ['anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking', 'DEATH_EVENT']]
sc = StandardScaler()
df2 = df.copy()
df[float_columns] = sc.fit_transform(df[float_columns])

#df.to_csv('Heart_Failure_scaled.csv', encoding='utf-8-sig')

X = df.drop(['DEATH_EVENT'], axis=1)
T = df['DEATH_EVENT']
X.head(10)
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  1.192945        0                  0.000166         0          -1.530560
# 1 -0.491279        0                  7.514640         0          -0.007077
# 2  0.350833        0                 -0.449939         0          -1.530560
# 3 -0.912335        1                 -0.486071         0          -1.530560
# 4  0.350833        1                 -0.435486         1          -1.530560
# 5  2.456114        1                 -0.552141         0           0.162199
# 6  1.192945        1                 -0.346704         0          -1.953749
# 7 -0.070223        1                 -0.275472         1           1.854958
# 8  0.350833        0                 -0.438583         0           2.278147
# 9  1.614001        1                 -0.473683         0          -0.260991
#
#    high_blood_pressure     platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  1.681648e-02          0.490057     -1.504036    1
# 1                    0  7.535660e-09         -0.284552     -0.141976    1
# 2                    0 -1.038073e+00         -0.090900     -1.731046    1
# 3                    0 -5.464741e-01          0.490057      0.085034    1
# 4                    0  6.517986e-01          1.264666     -4.682176    0
# 5                    1 -6.079240e-01          0.683709     -1.050016    1
# 6                    0 -1.396531e+00         -0.187726      0.085034    1
# 7                    0  1.952488e+00         -0.284552     -1.277026    1
# 8                    0  7.535660e-09          0.102752      0.312044    0
# 9                    1  1.276539e+00          7.752020     -0.823006    1
#
#    smoking      time
# 0        0 -1.629502
# 1        0 -1.603691
# 2        1 -1.590785
# 3        0 -1.590785
# 4        0 -1.577879
# 5        1 -1.577879
# 6        0 -1.552067
# 7        1 -1.552067
# 8        0 -1.552067
# 9        1 -1.552067

# %%
T.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: DEATH_EVENT, dtype: int64

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

Features = ['age', 'ejection_fraction', 'serum_creatinine']
X = df[Features]
#X = df.drop(['time','DEATH_EVENT'], axis=1)
print(X)
x_train, x_test, y_train, y_test = train_test_split(X, T, test_size=0.3, random_state=1)
# Out:
#           age  ejection_fraction  serum_creatinine
# 0    1.192945          -1.530560          0.490057
# 1   -0.491279          -0.007077         -0.284552
# 2    0.350833          -1.530560         -0.090900
# 3   -0.912335          -1.530560          0.490057
# 4    0.350833          -1.530560          1.264666
# ..        ...                ...               ...
# 294  0.098199          -0.007077         -0.284552
# 295 -0.491279          -0.007077         -0.187726
# 296 -1.333392           1.854958         -0.575031
# 297 -1.333392          -0.007077          0.005926
# 298 -0.912335           0.585389          0.199578
#
# [299 rows x 3 columns]

# %% [markdown]
# ## Modeling

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from colorama import Fore
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

accuracy_list=[]

# %% [markdown]
# ### Logistic Regression
# - 종속변수가 이분형일 때 수행할 수 있는 회귀 분석 기법의 한 종류
# - 오차를 기반으로 학습을 수행
# - **장점**
#     - 종속변수와 독립변수 사이의 관계가 비선형으로 식별되기 때문에 정규분포의 가정이 독립변수에 적용되지 않는다.
#     - 명목형, 연속형, 순서형을 비롯한 다양한 독립 변수에 다양한 자료 유형을 사용할 수 있기 때문에 복잡한 현상을 설명할 수 있다.
#     - 로지스틱회귀분석의 결과에는 각 요인에 대한 여러 분석값이 포함된다. 이러한 분서값은 다른 지역을 대상으로 하는 유사한 연구에 사용될 수 있다.
# - **단점**
#     - 종속변수가 발생할 가능성을 결정하기 위해 최적화된 회귀 방정식을 찾기 위한 계산을 반복하기 때문에 계산 프로세스를 추적할 수 없다는 점에서 한계가 있다.
#
# - **계산식**
# $
# z = b_0 + b_1x_1 + b_2x_2 + \dots + b_nx_n \\
# \text{P} = 1/(1+e^{-z}) \qquad \leftarrow \textbf{Sigmoid function} \\
# \text{J}(w) = -\cfrac{1}{n} \sum \limits _{i=1}^{n}[y^{(i)}\log H(x^{(i)}) + (1-y^{(i)})\log (1-H(x^{(i)}))]
# \qquad \leftarrow \textbf{Loss function(Cross Entropy, Logistic Loss)}
# $

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=1000,
                             #verbose=2
                            )
log_reg.fit(x_train, y_train)
log_reg_pred = log_reg.predict(x_test)
log_reg_acc = accuracy_score(y_test, log_reg_pred)
accuracy_list.append(100*log_reg_acc)
print(classification_report(y_test, log_reg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.86        64
#            1       0.69      0.42      0.52        26
#
#     accuracy                           0.78        90
#    macro avg       0.74      0.67      0.69        90
# weighted avg       0.77      0.78      0.76        90

# %%
print(Fore.GREEN + f"Accuracy of Logistic Regression is: {100*log_reg_acc:.2f}%")
# Out:
# Accuracy of Logistic Regression is: 77.78%

# %%
cm = confusion_matrix(y_test, log_reg_pred)
plt.figure()
plot_confusion_matrix(cm, figsize = (5,5), hide_ticks=True, cmap=plt.cm.Blues)
plt.title("Logistic Regression Model - Confusion Matrix")
plt.xticks(range(2), ["Heart Not Failed", "Heart Fail"], fontsize=16)
plt.yticks(range(2), ["Heart Not Failed", "Heart Fail"], fontsize=16)
plt.show()

# %% [markdown]
# ### Support Vector
# - 기본틀은 Linear Regression
# - MSE와 같은 오차가 아닌 **Margin**을 기반으로 학습
# - **계산식**
# $
# \textbf{w}^Tx+\textbf{b} = 0\\
# \qquad \textbf{w}\text{: normal vector(2차원에서 직선의 기울기와 같은 개념)} \\
# \qquad \textbf{b}\text{: bias(절편)} \\
# $
# 1. $\textbf{Margin}\text{: 데이터 포인트와 hyperplane 사이의 거리. 각 클래스의 데이터 중에서 경계선에 가장 가까이 있는 것.} \\
# \textbf{w}^Tx_{+} + \textbf{b} = 1 \\
# \textbf{w}^Tx_{-} + \textbf{b} = -1
# $
# 2. $\textbf{Support Vector}\text{: margin에서 hyperplane과 가장 가까이 있는 데이터 포인트} \\
# \text{즉, hyperplane과}\: (\frac{1}{2}\text{margin})\text{만큼 떨어져 있는 경계에 있으면서 margin decision에 영향을 주는 관측치}
# $
# 3. $\textbf{Kernel Trick}\text{: 커널은 실수, 함수, 벡터 등을 x,y 인자로 받고 실수를 출력하는 함수} \\
# \text{커널 트릭은 이런 커널 함수를 이용하여 데이터를 한 단계 높은 차원에서 보는 것}
# $

# %%
from sklearn.svm import SVC

sv_clf = SVC()
sv_clf.fit(x_train, y_train)
sv_clf_pred = sv_clf.predict(x_test)
sv_clf_acc = accuracy_score(y_test, sv_clf_pred)
accuracy_list.append(100*sv_clf_acc)

# %%
print(Fore.GREEN + f"Accuracy of SVC is: {100*sv_clf_acc:.2f}%")
# Out:
# Accuracy of SVC is: 78.89%

# %%
cm = confusion_matrix(y_test, sv_clf_pred)
plt.figure()
plot_confusion_matrix(cm, figsize=(5,5), hide_ticks=True, cmap = plt.cm.Blues)
plt.title("SVC Model - Confusion Matrix")
plt.xticks(range(2), ['Heart Not Failed','Heart Failed'])
plt.yticks(range(2), ['Heart Not Failed','Heart Failed'])
plt.show()

# %% [markdown]
# ### K Neighbors Classifier
# [Reference](https://bkshin.tistory.com/entry/머신러닝-6-K-최근접이웃KNN)
# <img src="./KNN.png" width="300px" height="250px" title="KNN"></img>
# - 새로운 데이터가 주어졌을 때(빨간점) 이를 Class A로 분류할지, Class B로 분류할지 판단하는 문제
# - K=3일 때, 노란점(Class A) 1개, 보라점(Class B) 2개
#     - Class B로 분류
# - K=6일 때, 노란점(Class A) 4개, 보라점(Class B) 2개
#     - Class A로 분류
# - K의 Default값은 5
# - 일반적으로 K는 홀수를 사용
#     - 짝수일 경우 동점이 생겨 하나의 결과를 도출하지 못할 수 있음
# - KNN은 훈련이 따로 필요가 없으며 Real-Time 예측이 이뤄진다. (Lazy Model이라고 불림)
#     - SVM이나 Linear Regression보다 빠르다
# - **거리계산**
#     - **Euclidean Distance**: 점과 점 사이의 거리
#     - **Manhatten Distance**: X축 Y축을 따라 간 거리

# %%
from sklearn.neighbors import KNeighborsClassifier

kn_clf = KNeighborsClassifier(n_neighbors=6)
kn_clf.fit(x_train, y_train)
kn_pred = kn_clf.predict(x_test)
kn_acc = accuracy_score(y_test, kn_pred)
accuracy_list.append(100*kn_acc)

# %%
print(Fore.GREEN + f"Accuracy of K Neighbors Classifier is : {100*kn_acc:.2f}%")
# Out:
# Accuracy of K Neighbors Classifier is : 74.44%

# %%
cm = confusion_matrix(y_test, kn_pred)

plt.figure()
plot_confusion_matrix(cm, figsize=(5,5), hide_ticks=True, cmap=plt.cm.Blues)
plt.title("K Neighbors Model - Confusion Matrix")
plt.xticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
plt.yticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
plt.show()

# %% [markdown]
# ### K Means Clustering

# %%
from sklearn.cluster import KMeans

kms = KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
               n_clusters=2, n_init=10, random_state=None, tol=0.0001, verbose=0)
kms.fit(x_train)
#print(Kmean.cluster_centers_)
kms_acc = accuracy_score(kms.labels_, y_train)
print(Fore.GREEN + f"Accuracy of K-Means Clusters is : {100*kms_acc:.2f}%")
# Out:
# Accuracy of K-Means Clusters is : 39.71%

# %%
import matplotlib.pyplot as plt
inertia = []
for k in range(2,7):
    kms =  KMeans(n_clusters=k)
    kms.fit(x_train)
    inertia.append(kms.inertia_)
plt.plot(range(2,7), inertia)
plt.xlabel('k')
plt.ylabel('inertia')
plt.show()

# %% [markdown]
# ### Decision Tree Classifier
# - Decision Tree: 데이터를 특정 기준으로(yes/no) **이진 분류**를 시키면서 특징별로 분류하는 모델
# - Classification과 Regression 모두 가능한 지도 학습 모델
#
# - 단점
#     - 모든 feature을 갖고 분류를 했을 경우 **과적합**이 이뤄지는 경우가 많음
#     - 이런 부분을 보안하여 나온 모델이 **Random Forest**
# - 보완
#     - 가지치기(Pruning)
#         - 트리에 가지가 너무 많으면 오버피팅이라고 볼 수 있음
#         - 최대 깊이나 터미널 노드의 최대개수 혹은 한 노드가 분할하기 위한 최소 데이터 수를 제한할 필요가 있음
#         - `min_sample_split`: 한 노드에 들어있는 최소 데이터 수 고정
#             - `min_sample_split=10`: 한 노드에 10개의 데이터가 있으면 더이상 분기를 하지 않음
#         - `max_depth`: 최대 깊이를 지정
#             - `max_depth=4`: 깊이가 4보다 크게 가지를 치지 않음
# - **Algorithm**: Entropy, Impurity
#     - **Impurity**
#         - 한 범주에 하나의 데이터만: Impurity 최소
#         - 한 범주에 서로 다른 두 데이터가 정확히 반반: Impurity 최대
#         - Decision Tree는 Impurity를 최소화하는 방향으로 학습을 진행
#     - **Entropy**
#         - Impurity를 수치적으로 나타낸 척도
#         - Entropy가 높다: Impurity가 크다 (최대: Entropy==1)
#         - Entropy가 낮다: Impurity가 낮다 (최소: Entropy==0)
#         - $\textbf{Entropy} = - \sum \limits _i(P_i)\log _2(p_i)\\
#         (\textbf{P}_i = \text{한 영역 안에 존재하는 데이터 가운데 범주 i에 속하는 데이터의 비율})$
#     - **Information gain**
#         - 엔트로피가 1인 상태에서 0.7로 바뀐다면 정보획득(Informatino gain)은 0.3
#         - $\textbf{Information gain} = \textbf{Entropy}(\text{parent})-[\textbf{weighted average}]\textbf{Entropy}(\text{children})$
#         - **Entropy(parent)**: 분기 이전 엔트로피
#         - **Entropy(children)**: 분기 이후 엔트로피
#         - **Weighted average**: 가중평균, 분기를 하면 범주가 2개 이상으로 쪼개지기 때문에 가중평균을 활용
# - **Decision Tree Algrorithm**은 **Information gain**을 최대화 하는 방향으로 학습이 진행
#     - 어느 feature의 어느 분기점에서 정보획득이 최대화되는지 판단해서 분기

# %%
from sklearn.tree import DecisionTreeClassifier

dt_clf = DecisionTreeClassifier(max_leaf_nodes=3, random_state=0, criterion='entropy')
dt_clf.fit(x_train, y_train)
dt_pred = dt_clf.predict(x_test)
dt_acc = accuracy_score(y_test, dt_pred)
accuracy_list.append(100*dt_acc)

# %%
print(Fore.GREEN + "Accuracy of Decision Tree Classifier is : ", "{:.2f}%".format(100* dt_acc))
# Out:
# Accuracy of Decision Tree Classifier is :  72.22%

# %%
cm = confusion_matrix(y_test, dt_pred)
plt.figure()
plot_confusion_matrix(cm, figsize=(5,5), hide_ticks=True, cmap=plt.cm.Blues)
plt.title("Decision Tree Model - Confusion Matrix")
plt.xticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
plt.yticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
plt.show()

# %% [markdown]
# ### Random Forest Classifier
# **(Resove Overfitting Problems of Decision Tree Model)**
# - Decision Tree의 과적합 등의 문제를 보안하여 나온 모델
# - 여러개의 Decision Tree들이 모여 **Bagging Ensemble**한 모델
#     - 예) Feature가 총 100개가 있을 때, 100개를 모두 사용하면 overfit되기 때문에 10~20개 정도를 선택해서 만든 **Decision Tree를 여러개 만들어서 Forest를 만듬**
#     - 핵심은 **여러 개**의 Weak Classifier를 결합하여 Strong Classifier를 만드는 것 (**Ensemble Learning**)
#     - 즉, 하나의 깊이가 깊은 Decision Tree를 만드는 것이 아닌 여러 개의 작은 Decision Tree를 만드는 것
#     - 여러 개의 작은 Decision Tree가 예측한 값들 중 가장 많은 값 혹은 평균값을 최종 예측값으로 정함
#     - 여러 개의 Decision Tree들의 경계를 평균내어 Random Forest를 만듬
# - `n_estimators`: Random Forest 안의 결정트리 개수.
#     - 해당 값이 클수록 더 깔끔한 Decision Boundary가 형성. 메모리와 Learning Time 증가
# - `max_features`: 무작위로 선택할 Feature 개수
#     - 해당 값이 전체 Feature 수와 같으면 전체 Feature 모두를 사용해서 Decision Tree를 형성.
#     - Bootstrap Params가 False면, 비복원 추출을 하기 때문에 전체 Features를 사용해서 트리를 형성
#     - Bootstrap Params가 True면, 복원 추출해서 트리를 만듬. (*default: bootstrap=True)
#     - 해당 값이 크면 Random Forest의 Tree들이 매우 비슷해지고, 가장 두드러진 특성에 맞게 예측을 할 것
#     - 해당 값이 작으면 Random Forest의 Tree들이 서로 매우 달라짐. Overfitting은 감소.
#     - 일반적으로 default값을 사용

# %% [markdown]
# **Ensemble**
# - 여러 개의 Decision Tree를 결합하여 하나의 결정 트리보다 더 좋은 성능을 내는 머신러닝 기법
# - Ensemble의 핵심
#     - 여러 개의 약 분류기(Weak Classifier)를 결합하여 강 분류기(Strong Classifier)를 만드는 것
# - 2가지 학습법
#     1. Bagging
#
#     2. Boosting

# %% [markdown]
# **Bootstrap**
# - 모수의 분포를 추정하는 좋은 방법은 현재 있는 표본에서 추가적으로 표본을 **복원 추출**하고 각 표본에 대한 통계량을 다시 계산하는 것
# - 이러한 절차를 부트스트랩이라고 함
# - 데이터가 정규분포를 따라야한다는 가정이 꼭 필요하지는 않음
# 예) 1억개의 모집단에서 뽑은 200개의 표본이 있을 때, 이 200개를 기준으로 복원 추출하여 새로운 통계량을 구하는 것
#     1. 200개의 표본 중 하나를 뽑아 기록하고 원위치
#     2. 위 과정을 n번 반복
#     3. n번 재표본추출한 값의 평균을 구함
#     4. 1~3 단계를 R번 반복 (**R: 부트스트랩 반복 횟수**)
#     5. 평균에 대한 결과 R개를 사용하여 신뢰구간 결정
# - 위 방법을 통해 표본이 200개밖에 없을지라도 200개보다 더 많은 통계량을 구할 수 있음

# %% [markdown]
# **Bagging**
# - **Bootstrap Aggregation**의 약자
# - Sample을 여러 번 뽑아(**Bootstrap**) 각 모델을 학습시켜 결과물을 집계(**Aggregation**)하는 방법
# 1. 데이터로부터 Bootstrap 실행.
# 2. Bootstrap한 데이터로 모델 학습
# 3. 학습된 모델의 결과를 집계하여 최정 결과값 도출
# 4. Categorical Data는 투표방식(Voting)으로 결과를 집계하며, Continuous Data는 평균으로 집계
#     - **Categorical Data**: 전체 모델에서 예측한 값 중 가장 많은 값을 최종 예측값으로 선정
#     - 6개 결정트리 모델이 있을 때, 4개는 A로, 2개는 B로 예측했다면, A를 최종 결과로 예측
#     - **Continuous Data**: 결정 트리 모델이 예측한 값에 평균을 취해 최종 Bagging Model의 예측값을 결정

# %% [markdown]
# <img src="./Bagging.png" width="700px" height="250px" title="Bagging"></img>

# %% [markdown]
# **Boosting**
# - 가중치를 활용하여 약 분류기를 강 분류기로 만드는 방법
# - **Bagging**은 Decision Tree1, Decision Tree2가 각각 독립적으로 결과를 예측. 여러 개의 독립적인 Decision Tree가 각각 값을 예측한 뒤 그 결과값을 집계(Aggregation)하여 최종 결과값을 예측
# - **Boosting**은 모델 간 팀워크가 이뤄짐.
# - 처음 모델이 예측을 하면 그 예측 결과에 따라 데이터에 가중치가 부여되고, 부여된 가중치가 다음 모델에 영향을 줌
# - 잘못 분류된 데이터에 집중하여 새로운 분류 규칙을 만드는 단계를 반복

# %% [markdown]
# <img src="./Boosting.png" width="700px" height="400px" title="Boosting"></img>

# %% [markdown]
# **Bagging and Boosting**
# <img src="./BaggingnBoosting.png" width="700px" height="250px" title="Bagging&Boosting"></img>
# - **Bagging**: 병렬로 학습
# - **Boosting**
#     1. 순차적으로 학습.
#     2. 학습 후 결과에 따라 가중치 부여.
#     3. 부여된 가중치가 다음 결과 예측에 영향
#     - 오답에 대해서는 높은 가중치를 부여, 정답에 대해서는 낮은 가중치를 부여
#     - 오답을 정답으로 맞추기 위해 오답에 더 집중
#     - Boosting이 상대적으로 Error가 더 낮음
#     - 하지만 속도가 느리고 Overfitting될 가능성이 있음
# - 개별 결정 트리의 **낮은 성능**이 문제 -> Boosting이 적합
# - **오버피팅**이 문제 -> Bagging이 적합

# %%
from sklearn.ensemble import RandomForestClassifier

r_clf = RandomForestClassifier(max_features=0.5, max_depth=15, random_state=1)
r_clf.fit(x_train, y_train)
r_pred = r_clf.predict(x_test)
r_acc = accuracy_score(y_test, r_pred)
accuracy_list.append(100*r_acc)

# %%
print(Fore.GREEN + "Accuracy of Random Forest Classifier is : ", "{:.2f}%".format(100* r_acc))
# Out:
# Accuracy of Random Forest Classifier is :  78.89%

# %%
cm = confusion_matrix(y_test, r_pred)
plt.figure()
plot_confusion_matrix(cm, figsize=(5,5), hide_ticks=True, cmap=plt.cm.Blues)
plt.title("Random Forest Model - Confusion Matrix")
plt.xticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
plt.yticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
plt.show()

# %% [markdown]
# ### Gradient Boosting Classifier
# - **Bagging**: Random Forest
# - **Boosting**: AdaBoost, Gradient Boost
# - Gradient Boost: 회귀와 분류에서 모두 사용이 가능
#
# - **Gradient Boost의 변형 모델**
#     1) XGBoost
#     2) LightBoost
#     3) CatBoost

# %% [markdown]
# **AdaBoost**
# [Reference](https://bkshin.tistory.com/entry/머신러닝-14-AdaBoost)
# - 하나의 Node에 두 개의 Leaf를 지닌 Tree를 Stump라고 함
# - AdaBoost는 여러 개의 Stump로 구성
# - Tree와 다르게 Stump는 정확한 분류를 하지 못함
#     - 여러 질문을 통해 데이터를 분류하는 Tree와는 다르게, Stump는 하나의 질문으로 데이터를 분류해야함
#     - 따라서 Stump는 약한 학습기로 분류(Weak Learner)

# %% [markdown]
# **RandomForest**는 여러 개의 Tree의 결과를 합산해 최종 결과를 도출. 각각의 Tree는 동등한 가중치를 가짐
# <img src="./RandomForest.png" width="400px" height="250px" title="RandomForest"></img>

# %% [markdown]
# **AdaBoost**는 특정 Stump가 다른 Stump보다 더 중요. 즉, 가중치가 더 높음(="**Amount of Say가 높다**","**결과에 미치는 영향이 크다**")
# <img src="./AdaBoost.png" width="400px" height="250px" title="AdaBoost"></img>
# - 첫 번째 Stump에서 발생한 Error는 두 번째 Stump의 결과에 영향
# - 두 번째 Stump에서 발생한 Error는 세 번째 Stump의 결과에 영햐
# - ...
#
# **결론**
# 1) 약한 학습기(Weak Learner)로 구성. 약한 학습기는 Stump 형태
# 2) 어떤 Stump는 다른 Stump보다 가중치가 높음(Amount of Say가 크다)
# 3) 각 Stump의 Error는 다음 Stump의 결과에 영향을 미침

# %% [markdown]
# **AdaBoost 작동 원리**
# - Sample이 8개, Training Feature가 3개일 때 (8x3 Matrix)
# 0) 초기 Sample Weight는 1/n으로 설정(=1/8)
# 1) 각 Feature마다 Stump 생산
# 2) 각 Feature들의 **Gini Index**를 구한 뒤 가장 작은 Gini Index에 해당하는 Feature의 Stump를 첫 Stump로 지정
# 3) Amoun of Say를 구함
#     - 모든 Sample Weight의 합은 1이므로, Total Error는 0과 1 사이의 값을 갖음
#     - Total Error가 Amount of Say를 결정
#     - Amount of Say는 최종 분류에 있어서 해당 Stump가 얼마만큼의 영향을 주는가를 뜻함
#     - **공식**
#     $
#     \textbf{Amount of Say} = \cfrac{1}{2}\log\cfrac{1-\text{Total Error}}{\text{Total Error}}
#     $
# <img src="./AmountofSay.png" width="300px" height="50px" title="AmountofSay"></img>
# - X축은 Total Error, Y축은 Amount of Say
# - Total Error가 0이면 Amount of Say는 굉장히 큰 양수
# - Total Error가 1이면 Amount of Say는 굉장히 작은 음수
# - Total Error가 0.5이면 Amount of Say는 0(의미가 없음)
# 4) Sample Weight Settitng
#     - **공식**
#     $\textbf{New Sample Weight} = \text{Sample Weight}\times e^\text{Amount of Say}$
#     - **예)**
#     $\textbf{이전 Stump에서 잘못 분류된 Sample}$
#     $\rightarrow\text{Total Error} = \cfrac{1}{8},$
#     $\rightarrow\text{Amount of Say} = \cfrac{1}{2} \log (\cfrac{1-\cfrac{1}{8}}{\cfrac{1}{8}}) = 0.97$
#     $\rightarrow\text{New Sample Weight} = \cfrac{1}{8}\times e^{0.97} = \cfrac{1}{8}\times{2.64} = 0.33$
#     $\text{기존 weight인 0.125보다 커졌다}$
#     $\textbf{이전 Stump에서 맞게 분류된 Sample}$
#     $\rightarrow\text{New Sample Weight} = \cfrac{1}{8}\times e^{-0.97} = \cfrac{1}{8}\times{0.38} = 0.05$
#     $\text{기존 weight인 0.125보다 작아졌다}$
#     $\text{이전 Stump에서 잘못 분류한 Sample에는 Sample Weight를 높여주고, 제대로 분류한 Sample에는 Sample Weight를 낮춤}$
#     $\text{그래야 다음 Stump에서 이전 Stump에서 잘못 분류한 것에 더 집중해서 올바르게 분류해줌}$
#     $\text{이후 새로 구해진 New Sample Weight들을 Normalization}$
# - New Table
# 5) Sampling으로 새로운 테이블을 생성
#     - 0부터 1까지 숫자를 무작위로 선택
#     - 0.00~0.07 사이 숫자가 나오면 첫 번째 Sample을 선택
#     - 0.07~0.14 사이 숫자가 나오면 두 번째 Sample을 선택
#     - 0.14~0.21 사이 숫자가 나오면 세 번째 Sample을 선택
#     - 0.21~0.70 사이 숫자가 나오면 네 번째 Sample을 선택 (상대적으로 많이 선택됨)
# - Repeat
# 6) 원래 테이블은 지우고 Sampling한 새로운 테이블을 가져옴
# 7) 모든 Sample의 Weight는 다시 1/n로 초기화(=1/8)
# 8) 1)단계부터 반복

# %% [markdown]
# **최종분류**
# - 여러 차례 진행하면 각 Stump마다 Amount of Say가 나옴
# - 각 Stump의 Amount of Say를 더하면 Total Amount of Say가 나오며, Total Amount of Say값이 큰쪽으로 선택

# %% [markdown]
# **AdaBoost와 Gradient Boost의 차이**
# - AdaBoost
#     - Stump로 구성. 하나의 Stump에서 발생한 Error가 다음 Stump에 영향을 미침. 이런식으로 여러 Stump가 순차적으로 연결
# - Gradient Boost
#     - Stump나 Tree가 아닌 하나의 Leaf(Single Leag)부터 시작
#     - 이 Leaf는 타겟 값에 대한 초기 추정값을 나타냄
#     - 보통은 초기 추정값을 평균으로 정함
#     - 이후 AdaBoost와 동일하게 이전 Tree의 Error가 다음 Tree에 영향을 미침
#     - 하지만 AdaBoost와 다르게 Stump가 아닌 Tree로 구성
#     - 보통 Leaf가 8개에서 32개인 Tree로 구성

# %% [markdown]
# **Gradient Boost Process**
# [Reference](https://bkshin.tistory.com/entry/머신러닝-15-Gradient-Boost)
# 1) Target Data들의 평균을 구함
# - Single Leaf로 예측한다고 하면 모든 Sample들을 1)값으로 예측
#
# 2) Single Leaf에서 예측한 값과 실제 값과의 차이(Error)를 구함(=Pseudo Residual)
# - $\text{(Real Value)}-\text{(Single Leaf Value)} = \textbf{Pseudo Residual}$
#
# 3) Residual을 예측하는 새로운 Tree를 생성
# - 마지막 Leaf node에 두 개의 Residual값이 있을 경우 평균으로 치환하여 넣어줌
#
# 4) 아래 방식으로 새로운 Residual를 업데이트
# - **New Residual_2** = (**Real Value** - (**Initial Value** + (**Learning Rate**)x(**Residual Value_1**)))
# - **New Residual_3** = (**Real Value** - (**Initial Value** + (**Learning Rate**)x(**Residual Value_1**)+ (**Learning Rate**)x(**Residual Value_2**)))
#
# 5) New Residual값이 더이상 작아지지 않거나 정해놓은 Iteration 횟수에 도달하면 반복을 종료
# 6) Gradient Boost Model 완료
# 7) 새로운 데이터가 주어지면 본 모델로 예측

# %%
from sklearn.ensemble import GradientBoostingClassifier

gradientboost_clf = GradientBoostingClassifier(max_depth=2, random_state=1)
gradientboost_clf.fit(x_train, y_train)
gradientboost_pred = gradientboost_clf.predict(x_test)
gradientboost_acc = accuracy_score(y_test, gradientboost_pred)
accuracy_list.append(100*gradientboost_acc)

# %%
print(Fore.GREEN + "Accuracy of Gradient Boosting is : ", "{:.2f}%".format(100* gradientboost_acc))
# Out:
# Accuracy of Gradient Boosting is :  74.44%

# %%
cm = confusion_matrix(y_test, gradientboost_pred)
plt.figure()
plot_confusion_matrix(cm, figsize=(5,5), hide_ticks=True, cmap=plt.cm.Blues)
plt.title("Gredient Boosting Model - Confusion Matrix")
plt.xticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
plt.yticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
plt.show()

# %% [markdown]
# ### XGBoost
# **(Gradient Boost + Parallel Learning)**
# - 여러개의 의사결정나무를 앙상블한 알고리즘
# - XGBoost는 RandomForest와 달리 **Gradient Boosting 앙상블**로 구현된 모델
# - boosting방식이란, **한 개의 예측모델**에 대한 error를 줄이는 방식의 앙상블 기법
#     - 예) 첫 번째 의사결정 나무가 있어 이를 통한 예측 모델이 있을 때, 이것의 오차값을 다시 의사결정나무로 오차를 줄이고 그 오차를 똑같은 방식으로 줄여나가는 방식
# - Gradient boost(GBM)와 같은 방식의 앙상블 모델이지만, **병렬 학습**이 지원되어 더 빠른 학습이 가능해짐
# - Level-wise tree

# %%
from xgboost import XGBClassifier
xgb_clf = XGBClassifier(eval_metric='mlogloss',
                            use_label_encoder =False,
                            max_depth=3,
                            random_state=1)
xgb_clf.fit(x_train, y_train)
xgb_pred = xgb_clf.predict(x_test)
xgb_acc = accuracy_score(y_test, xgb_pred)

print(classification_report(y_test, xgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83        64
#            1       0.57      0.46      0.51        26
#
#     accuracy                           0.74        90
#    macro avg       0.68      0.66      0.67        90
# weighted avg       0.73      0.74      0.74        90

# %%
print(Fore.GREEN + "Accuracy of XGBClassifier is : ", "{:.2f}%".format(100* xgb_acc))
# Out:
# Accuracy of XGBClassifier is :  74.44%

# %%
plt.bar(X.columns, xgb_clf.feature_importances_)
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
sns.jointplot(x='ejection_fraction', y='serum_creatinine', data=df, hue='DEATH_EVENT')
plt.show()

# %% [markdown]
# ### Precision Recall Curve
# **Precision** or **Positive Predictive Value(PPV)**
# - $\textbf{PPV} = \cfrac{\textbf{TP}}{\textbf{TP}+\textbf{FP}} = 1 - \textbf{FDR}$
# - TP & FP: Positive라고 예측한 것들의 집합. Positive라고 예측 후 정답이면 TP, 오답이면 FP
# - 모델이 Positive라고 예측한 것들 중에서 얼마나 정답을 잘 맞췄는지에 대한 비율이 Precision
# - **FDR**(False Discovery Rate): $\cfrac{\textbf{False Positive}}{\textbf{Total Positive}}$
#
# **Recall, Sensitivity, Hit Rate** or **True Positive Rate(TPR)**
# - $\textbf{TPR} = \cfrac{\textbf{TP}}{\textbf{P}} = \cfrac{\textbf{TP}}{\textbf{TP}+\textbf{FN}} = 1 - \textbf{FNR}$
# - Recall의 의미는 P 중에서 TP. 즉, 실제 Positive들 중에서 모델이 예측한 Positive의 비율
#
# **Precision Recall Curve**
# [Reference](https://bskyvision.com/465)
# - X축: **Recall**
# - Y축: **Precision**
# - AP: **Average Precision**
# - Precision이 높으면 Recall은 낮은 경향이 있고, Precision이 낮으면 Recall은 높은 경향이 있음
# - **두 값을 종합**해서 알고리즘의 성능을 평가
# - PR-Curve는 **Confidence Level**에 대한 **threshold** 값의 변화에 의한 물체 검출기의 성능을 평가하는 방법
# - Confidence Level은 검출한 것에 대해 알고리즘이 얼마나 확신이 있는지 알려주는 값
# - Confidence Level에 대해 threshold 값을 부여해서 특정값 이상이 되어야 검출된 것으로 인정
# - 예) threshold 값이 0.4라면 confidence 레벨로 0.1 또는 0.2를 갖고 있는 검출은 무시
# - **AP**: PR-Curve에서 그래프 선 아래쪽의 면적
# - 컴퓨터 비전 분야에서 물체 검출 및 이미지 분류 알고리즘의 성능은 대부분 이 AP로 평가

# %%
from sklearn.metrics import PrecisionRecallDisplay

fig = plt.figure()
ax = fig.gca()

PrecisionRecallDisplay.from_estimator(
    log_reg, x_test, y_test, ax = ax
)
PrecisionRecallDisplay.from_estimator(
    xgb_clf, x_test, y_test, ax = ax
)
plt.title("Precision-Recall-Curve")
plt.show()

# %% [markdown]
# ### ROC Curve
# **Receiver Operating Characteristic Curve**
# - FPR과 TPR을 각각 X축, Y축으로 놓는 그래프
# - 면적이 1에 가까울수록 좋은 성능
# - 면적이 0.5이면 랜덤에 가까운 성능, 면적이 1이면 최고성능
# - $\textbf{TPR}$(= Sensitivity, Recall, Hit Rate)
# - $\textbf{FPR}$(=1-Specificity)$\;= \cfrac{\textbf{FP}}{\textbf{FP}+\textbf{TN}}$

# %%
from sklearn.metrics import RocCurveDisplay

fig = plt.figure()
ax = fig.gca()
RocCurveDisplay.from_estimator(log_reg, x_test, y_test, ax=ax) #위쪽에 그려질 수록 좋은 모델, AUC 값이 클수록 좋음
RocCurveDisplay.from_estimator(xgb_clf, x_test, y_test, ax=ax)
plt.title("ROC-Curve")
plt.show()

# %% [markdown]
# ### XGBRF Classifier
# **(XGBoost Random Forest)**
# [Reference1](https://cppsecrets.com/users/1512411697110100114105109971151051101031049752495764103109971051084699111109/PYTHON-XGBOOST-RANDOM-FOREST-AS-XGBOOST-MODEL.php)
# [Reference2](https://xgboost.readthedocs.io/en/stable/tutorials/rf.html)
# **XGBoost** also comes with XGBRFRegressor and **XGBRFClassifier** to build **Random Forests**
# - `n_estimators`: Speifies the size of the forest to be trained(not gradient boosting but bagging trees in one round only);
#     - It is converted to `num_parallel_tree`, instead of the number of boosting rounds
# - `learning_rate`: Set to 1 by default
# - `subsample`: must be set to a value less than 1 to enable random selection of training cases(rows)
# - One of `colsample_by*`: must be set to a value less than 1 to enable random selection of columns
#     - Normally, `colsample_bynode` would be set to a value less than 1 to randomly sample columns at each tree split
#     - Scikit-learn's random forest keeps these defaults at 1, making the default XGBRFRegressor and XGBRFClassifier is **less prone to overfitting**(*default: 0.8)
# - `num_parallel_tree`: Set to the size of the forest being trained
# - `num_boost_round`: Set to 1 to prevent XGBoost from boosting multiple random forests
# - `eta`:  (alias: `learning_rate`) must be set to 1 when training random forest regression
# - `random_state`
# - `booster`: Always `gbtree`
#
# **Sample**
# `params = {
#   'colsample_bynode': 0.8,
#   'learning_rate': 1,
#   'max_depth': 5,
#   'num_parallel_tree': 100,
#   'objective': 'binary:logistic',
#   'subsample': 0.8,
#   'tree_method': 'gpu_hist'
# }`

# %%
from xgboost import XGBRFClassifier

xgbrf_clf = XGBRFClassifier(eval_metric='mlogloss',
                            use_label_encoder =False,
                            max_depth=3,
                            random_state=1)
xgbrf_clf.fit(x_train, y_train)
xgbrf_pred = xgbrf_clf.predict(x_test)
xgbrf_acc = accuracy_score(y_test, xgbrf_pred)
accuracy_list.append(100*xgbrf_acc)
                     
print(classification_report(y_test, xgbrf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86        64
#            1       0.68      0.58      0.62        26
#
#     accuracy                           0.80        90
#    macro avg       0.76      0.73      0.74        90
# weighted avg       0.79      0.80      0.79        90

# %%
print(Fore.GREEN + "Accuracy of XGBRFClassifier is : ", "{:.2f}%".format(100* xgbrf_acc))
# Out:
# Accuracy of XGBRFClassifier is :  80.00%

# %%
plt.plot(xgbrf_clf.feature_importances_)

# %% [markdown]
# ### LGBM Classifier
# **(Unlike others, Expand vertically)**
#
#
# [**Reference...**](https://nurilee.com/2020/04/03/lightgbm-definition-parameter-tuning/)
# - **Gradient Boosting Framework**
# - ML Algorithm based on **Tree Model**
#     - Light GBM: **Tree가 수직적으로 확장**
#         - Leaf-wise 방식
#         <img src="./Leaf_wise_tree_growth.png" width="500px" height="400px" title="Leaf_wise"></img>
#     - Others: **Tree가 수평적으로 확장**
#         - Level-wise 방식
#         <img src="./Level_wise_tree_growth.png" width="400px" height="250px" title="Level_wise"></img>
#
# - **Light GBM이 인기를 얻게된 이유**
#     - 속도가 빠름
#     - 큰 사이즈의 데이터를 다룰 수 있으며 적은 메모리 공간을 차지
#     - 정확도가 높음
#     - GPU 학습을 지원
#     - 병렬 처리 지원
# - **Light GBM 사용처**
#     - 작은 데이터셋에는 부적합
#     - Overfitting에 민감
#     - row size에 대한 제한은 없으나 10,000개 이상에 권장
# - **Light GBM 구현**
#     - Parameter tuning이 복잡 (100개 이상)

# %% [markdown]
# **Parameters**
# - `max_depth`:
#     - Tree의 최대 깊이. 과적합을 해결할 때 사용
# - `min_data_in_leaf`:
#     - Leaf가 가지고 있는 최소한의 레코드 수
#     - 과적합을 해결할 때 사용
#     - 큰 값으로 세팅함으로써 Tree가 너무 깊게 확장되는 것을 방지할 수 있음
#         - 하지만 underfitting이 발생할 수 있음
#     - 관행적으로 수백~수천 개로 정하는 것이 큰 데이터셋에서 충분
#     - *default value 20
# - `feature_fraction`:
#     - Boosting이 Random Forest일 경우 사용
#     - 0.8 feature_fraction
#         - Light GBMdl Tree를 만들 때 매번 각각의 iteration 반복에서 파라미터 중에 80%를 랜덤하게 선택
# - `bagging_fraction`:
#     - 매번 iteration을 돌 때 사용되는 데이터의 일부를 선택하는데 트레이닝 속도를 높이고 과적합을 방지할 때 주로 사용
# - `early_stopping_round`:
#     - 분석 속도를 높이는데 도움을 줌
#     - 모델은 만약 어떤 validation 데이터 중 하나의 지표가 지난 early_stopping_round 라운드에서 향상되지 않았다면 학습을 중단함
#         - 이는 지나친 iteration을 줄이는데 도움을 줌
# - `lambda`:
#     - lambda값은 regularization 정규화를 함
#     - 0~1 사이
# - `min_gain_to_split`:
#     - 분기하기 위해 필요한 최소한의 gain을 의미
#     - Tree의 유용한 분기수를 컨트롤하는데 사용
# - `max_cat_group`:
#     - 카테고리 수가 클 때, 과적합을 방지하는 분기포인트를 찾음
#     - Light GBM 알고리즘이 카테고리 그룹을 max_cat_group 그룹으로 합치고 그룹 경계선에서 분기 포인트를 찾음
#     - *default value 64
#
# **Core Parameters**
# - `Task`:
#     - 데이터에 대해서 수행하고자 하는 임무를 구체화
#     - training or prediction
# - `application`:
#     - 가장 중요한 파라미터로, 모델의 어플리케이션을 정함
#     - regression or classification
#     - dafault value $\text{regression}$
#         - regression: 회귀분석
#         - binary: 이진 분류
#         - multiclass: 다중 분류
# - `boosting`:
#     - 실행하고자 하는 알고리즘 타입을 정의
#     - default value $\text{gdbt}$
#         - gdbt: Traditional Gradient Boosting Decision Tree
#         - rf: Random Forest
#         - dart: Dropouts meet Multiple Additive Regression Trees
#         - goss: Gradient-based One-Side Sampling
# - `num_boost_round`:
#     - boosting iteration 수로 일반적으로 100 이상
# - `learning_rate`:
#     - 최종 결과에 대한 각각의 Tree에 영향을 미치는 변수
#     - GBM은 초기 수정값에서 시작하여 각각의 Tree 결과를 사용하여 추정값을 업데이트
#     - 학습 파라미터는 이러한 추정에서 발생하는 변화의 크기를 컨트롤
#     - 일반적인 값으로 0.1, 0.001, 0.003 등이 있음
# - `num_leaves`:
#     - Tree 모델의 복잡성을 컨트롤하는 주요 파라미터
#     - 전체 Tree의 leaves 수를 나타냄
#     - 이상적으로 num_leaves 값은 2**(max_depth)값보다 적거나 같아야 함
#         - 이 것보다 많으면 과적합 유발
#     - default value 31
# - `device`:
#     - default value $\text{cpu}$
#
# **Metric Parameter**
# - `metric`:
#     - 모델을 구현할 때 손실을 정리하기 때문에 중요한 변수 중 하나
#     - regression과 classification을 위한 일반적인 손실 값으로
#         - mae: mean absolute error
#         - mse: mean squared error
#         - binary_logloss: loss for binary classification
#         - multi_logloss: loss for multi classification
#
# **IO Parameter**
# - `max_bin`:
#     - feature 값의 최대 bin 수를 의미
# - `categorical_features`:
#     - 범주형 feature 인덱스를 의미
#     - categorical_features가 0,1,2 이면 column 0, column 1, column 2가 범주형 변수들
# - `ignore_column`:
#     - categorical_features와 거의 동일
#     - feature로써 특정 칼럼을 고려하지 않음 (해당 변수들을 무시)
# - `save_binary`:
#     - 데이터 파일의 메모리 사이즈를 처리해야한다면 해당 파라미터를 True로 설정
#     - 해당 값이 True일 때, 데이터 세트는 바이너리 파일로 저장
#     - 이 바이너리 파일은 다음에 데이터를 읽어올 때 그 속도를 줄여줌

# %% [markdown]
# **더 빠른 속도**
# - `bagging_fraction` & `baggin_freq`를 설정하여 bagging을 적용
# - `feature_fraction`을 설정하여 feature sub-sampling을 시도
# - 작은 `max_bin` 값 적용
# - `save_binary`를 통해 향후 학습에서 데이터 로딩 속도를 감소
# - parallel learning 시도
#
# **더 높은 정확도**
# - 큰 `max_bin` 값 적용
# - 작은 `learning_rate`값을 큰 `num_iterations`값과 함께 적용
# - 큰 `num_leaves`값을 사용 (과적합을 유발)
# - 더 큰 traing data 사용
# - dart 사용
# - categorical feature 사용
#
# **과적합 해결**
# - 작은 `max_bin` 값 사용
# - 작은 `num_leaves` 값을 사용
# - `min_data_in_leaf`와 `min_sum_hessian_in_leaf` 파라미터를 사용
# - `bagging_fraction`과 `bagging_freq`를 사용하여 bagging을 적용
# - `feature_fraction`을 설정하여 feature sub-sampling을 시도
# - lambda_l1, lambda_l2 그리고 `min_gain_to_split` 파라미터를 이용해 regularization을 적용
# - `max_depth`를 설정해서 Deep Tree가 만들어지는 것을 방지

# %%
import lightgbm as lgb

lgb_clf = lgb.LGBMClassifier(max_depth=2,random_state=4)
lgb_clf.fit(x_train, y_train)
lgb_pred = lgb_clf.predict(x_test)
lgb_acc = accuracy_score(y_test, lgb_pred)
accuracy_list.append(100*lgb_acc)

# %%
print(Fore.GREEN + f'Accuracy of LGBM Classifier is : {100*lgb_acc:.2f}%')
# Out:
# Accuracy of LGBM Classifier is : 76.67%

# %%
cm = confusion_matrix(y_test, lgb_pred)
plt.figure()
plot_confusion_matrix(cm, figsize=(5,5), hide_ticks=True, cmap=plt.cm.Blues)
plt.title("LGBMClassifier Model - Confusion Matrix")
plt.xticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
plt.yticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
plt.show()

# %%
d_train = lgb.Dataset(x_train, label=y_train)
params={}
params['boosting_type'] = 'gbdt'
params['num_leaves'] = 2
params['max_depth'] = 2
#params['max_bin'] = 1000
params['learning_rate'] = 0.1
params['force_row_wise']=True
params['objective'] = 'binary'

lgb_clf2 = lgb.train(params, d_train)
# Out:
# [LightGBM] [Info] Number of positive: 70, number of negative: 139
# [LightGBM] [Info] Total Bins 67
# [LightGBM] [Info] Number of data points in the train set: 209, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.334928 -> initscore=-0.685979
# [LightGBM] [Info] Start training from score -0.685979

# %%
import numpy as np

lgb_pred2 = lgb_clf2.predict(x_test)
preds_ld = lgb_pred2.flatten()
pred_class = np.where(preds_ld >=0.5, 1, 0)
lgb_acc2 = accuracy_score(y_test, pred_class)
print(Fore.GREEN + f'Accuracy of LGBM Classifier is : {100*lgb_acc2:.2f}%')
# Out:
# Accuracy of LGBM Classifier is : 75.56%

# %% [markdown]
# ### Cat Boost Classifier
# **(Resolve Overfitting Problems of LGBM)**
# - LightGBM의 과적합 문제점을 해결하기 위해 만들어진 모델
# - 범주형 변수의 예측모델에 최적화
# 1. **Level-wise 방식의 모델 생성**
# 2. **Ordered boosting 방식으로 부스팅**
#     - General boosting은 **전체적인 오차**에 대한 값으로 모델을 앙상블
#     - Ordered boosting은 **부분의 오차**에 대해 모델을 생성하고 데이터들을 늘려나감
#         - 이 방식으로 과적합을 줄임
# 3. **Ordered Target Encoding(Mean Encoding) 범주형 변수 변환**
#     - 독립변수의 범주형 변수가 종속변수의 평균으로 인코딩
#     - 독립변수가 일반적인 0,1으로 인코딩했을 때보다 data와의 연관성이 생김
# 4. **Categorical Feature Combinations 범주형 변수 결합**
#     - 연관된 범주형 변수를 자동으로 결합시켜줌으로써 변수를 줄임
# - **장점**: 범주형 변수에 대해서 특정 인코딩 방식을 통해 정확도와 속도를 높임
# - **단점**: 연속형 변수가 많을 경우 catboost 속도가 현저하게 떨어짐
# - 결과적으로 catboost를 사용할 때 변수들을 범주형으로 만들려는 노력을 많이해야함

# %%
from catboost import CatBoostClassifier

cat_clf = CatBoostClassifier()
cat_clf.fit(x_train,y_train)
cat_pred = cat_clf.predict(x_test)
cat_acc = accuracy_score(y_test, cat_pred)
accuracy_list.append(100*cat_acc)
# Out:
# Learning rate set to 0.00528
# 0:	learn: 0.6906382	total: 1.14ms	remaining: 1.14s
# 1:	learn: 0.6888626	total: 1.45ms	remaining: 725ms
# 2:	learn: 0.6861952	total: 1.78ms	remaining: 593ms
# 3:	learn: 0.6841590	total: 2.1ms	remaining: 522ms
# 4:	learn: 0.6818751	total: 2.33ms	remaining: 464ms
# 5:	learn: 0.6797982	total: 2.6ms	remaining: 431ms
# 6:	learn: 0.6772450	total: 2.83ms	remaining: 402ms
# 7:	learn: 0.6757997	total: 3.02ms	remaining: 374ms
# 8:	learn: 0.6733027	total: 3.25ms	remaining: 358ms
# 9:	learn: 0.6713005	total: 3.44ms	remaining: 341ms
# 10:	learn: 0.6693304	total: 3.65ms	remaining: 328ms
# 11:	learn: 0.6675637	total: 3.83ms	remaining: 315ms
# 12:	learn: 0.6659445	total: 4.2ms	remaining: 319ms
# 13:	learn: 0.6640806	total: 4.49ms	remaining: 316ms
# 14:	learn: 0.6619090	total: 4.73ms	remaining: 311ms
# 15:	learn: 0.6596213	total: 5.1ms	remaining: 313ms
# 16:	learn: 0.6573162	total: 5.36ms	remaining: 310ms
# 17:	learn: 0.6558709	total: 5.57ms	remaining: 304ms
# 18:	learn: 0.6539712	total: 5.7ms	remaining: 295ms
# 19:	learn: 0.6517154	total: 5.89ms	remaining: 289ms
# 20:	learn: 0.6496740	total: 6.14ms	remaining: 287ms
# 21:	learn: 0.6473896	total: 6.41ms	remaining: 285ms
# 22:	learn: 0.6455529	total: 6.56ms	remaining: 279ms
# 23:	learn: 0.6433144	total: 6.82ms	remaining: 277ms
# 24:	learn: 0.6412906	total: 7.04ms	remaining: 275ms
# 25:	learn: 0.6388805	total: 7.33ms	remaining: 275ms
# 26:	learn: 0.6368972	total: 7.57ms	remaining: 273ms
# 27:	learn: 0.6350485	total: 7.75ms	remaining: 269ms
# 28:	learn: 0.6337204	total: 7.94ms	remaining: 266ms
# 29:	learn: 0.6319455	total: 8.15ms	remaining: 264ms
# 30:	learn: 0.6303553	total: 8.44ms	remaining: 264ms
# 31:	learn: 0.6283648	total: 8.73ms	remaining: 264ms
# 32:	learn: 0.6261887	total: 8.93ms	remaining: 262ms
# 33:	learn: 0.6239733	total: 9.15ms	remaining: 260ms
# 34:	learn: 0.6221932	total: 9.48ms	remaining: 261ms
# 35:	learn: 0.6200146	total: 9.74ms	remaining: 261ms
# 36:	learn: 0.6185311	total: 10.1ms	remaining: 262ms
# 37:	learn: 0.6168041	total: 10.5ms	remaining: 265ms
# 38:	learn: 0.6149083	total: 10.7ms	remaining: 265ms
# 39:	learn: 0.6131124	total: 11ms	remaining: 265ms
# 40:	learn: 0.6116330	total: 11.3ms	remaining: 264ms
# 41:	learn: 0.6096396	total: 11.5ms	remaining: 262ms
# 42:	learn: 0.6083450	total: 11.8ms	remaining: 262ms
# 43:	learn: 0.6060459	total: 12ms	remaining: 262ms
# 44:	learn: 0.6040438	total: 12.3ms	remaining: 262ms
# 45:	learn: 0.6026203	total: 12.6ms	remaining: 261ms
# 46:	learn: 0.6008068	total: 12.8ms	remaining: 259ms
# 47:	learn: 0.5991410	total: 13ms	remaining: 258ms
# 48:	learn: 0.5974896	total: 13.2ms	remaining: 257ms
# 49:	learn: 0.5963853	total: 13.3ms	remaining: 254ms
# 50:	learn: 0.5946247	total: 13.6ms	remaining: 253ms
# 51:	learn: 0.5931420	total: 13.8ms	remaining: 252ms
# 52:	learn: 0.5914665	total: 14ms	remaining: 250ms
# 53:	learn: 0.5896764	total: 14.3ms	remaining: 250ms
# 54:	learn: 0.5883478	total: 14.5ms	remaining: 249ms
# 55:	learn: 0.5864624	total: 14.7ms	remaining: 247ms
# 56:	learn: 0.5851893	total: 14.9ms	remaining: 246ms
# 57:	learn: 0.5836458	total: 15.2ms	remaining: 247ms
# 58:	learn: 0.5822648	total: 15.3ms	remaining: 245ms
# 59:	learn: 0.5807239	total: 15.6ms	remaining: 245ms
# 60:	learn: 0.5790910	total: 16ms	remaining: 246ms
# 61:	learn: 0.5777047	total: 16.4ms	remaining: 248ms
# 62:	learn: 0.5764351	total: 16.8ms	remaining: 249ms
# 63:	learn: 0.5750320	total: 17.1ms	remaining: 250ms
# 64:	learn: 0.5741647	total: 17.3ms	remaining: 248ms
# 65:	learn: 0.5725769	total: 17.5ms	remaining: 247ms
# 66:	learn: 0.5709936	total: 17.7ms	remaining: 246ms
# 67:	learn: 0.5697049	total: 17.9ms	remaining: 245ms
# 68:	learn: 0.5685610	total: 18.2ms	remaining: 246ms
# 69:	learn: 0.5671163	total: 18.5ms	remaining: 245ms
# 70:	learn: 0.5657168	total: 18.7ms	remaining: 245ms
# 71:	learn: 0.5643841	total: 18.9ms	remaining: 244ms
# 72:	learn: 0.5631631	total: 19.1ms	remaining: 243ms
# 73:	learn: 0.5620215	total: 19.3ms	remaining: 242ms
# 74:	learn: 0.5610106	total: 19.5ms	remaining: 240ms
# 75:	learn: 0.5599131	total: 19.8ms	remaining: 241ms
# 76:	learn: 0.5589995	total: 20.1ms	remaining: 241ms
# 77:	learn: 0.5581337	total: 20.4ms	remaining: 241ms
# 78:	learn: 0.5563899	total: 20.6ms	remaining: 240ms
# 79:	learn: 0.5552076	total: 20.8ms	remaining: 239ms
# 80:	learn: 0.5542967	total: 21.2ms	remaining: 240ms
# 81:	learn: 0.5531723	total: 21.6ms	remaining: 241ms
# 82:	learn: 0.5519847	total: 21.8ms	remaining: 240ms
# 83:	learn: 0.5509772	total: 22ms	remaining: 240ms
# 84:	learn: 0.5499155	total: 22.1ms	remaining: 238ms
# 85:	learn: 0.5488102	total: 22.3ms	remaining: 237ms
# 86:	learn: 0.5477563	total: 22.6ms	remaining: 237ms
# 87:	learn: 0.5469744	total: 23ms	remaining: 238ms
# 88:	learn: 0.5455665	total: 23.3ms	remaining: 238ms
# 89:	learn: 0.5445345	total: 23.6ms	remaining: 239ms
# 90:	learn: 0.5437310	total: 23.9ms	remaining: 238ms
# 91:	learn: 0.5430189	total: 24.1ms	remaining: 238ms
# 92:	learn: 0.5421773	total: 24.5ms	remaining: 239ms
# 93:	learn: 0.5414854	total: 24.8ms	remaining: 239ms
# 94:	learn: 0.5406202	total: 25.1ms	remaining: 239ms
# 95:	learn: 0.5399378	total: 25.4ms	remaining: 239ms
# 96:	learn: 0.5390223	total: 25.6ms	remaining: 239ms
# 97:	learn: 0.5379519	total: 25.9ms	remaining: 239ms
# 98:	learn: 0.5372243	total: 26.3ms	remaining: 239ms
# 99:	learn: 0.5365757	total: 26.5ms	remaining: 238ms
# 100:	learn: 0.5350187	total: 26.7ms	remaining: 238ms
# 101:	learn: 0.5340130	total: 27ms	remaining: 238ms
# 102:	learn: 0.5331237	total: 27.3ms	remaining: 237ms
# 103:	learn: 0.5318751	total: 27.5ms	remaining: 237ms
# 104:	learn: 0.5305919	total: 27.9ms	remaining: 237ms
# 105:	learn: 0.5301532	total: 28ms	remaining: 236ms
# 106:	learn: 0.5295200	total: 28.4ms	remaining: 237ms
# 107:	learn: 0.5285764	total: 28.6ms	remaining: 236ms
# 108:	learn: 0.5274088	total: 28.8ms	remaining: 236ms
# 109:	learn: 0.5264392	total: 29.2ms	remaining: 236ms
# 110:	learn: 0.5254564	total: 29.5ms	remaining: 236ms
# 111:	learn: 0.5244076	total: 29.8ms	remaining: 236ms
# 112:	learn: 0.5233351	total: 30.1ms	remaining: 236ms
# 113:	learn: 0.5227124	total: 30.3ms	remaining: 235ms
# 114:	learn: 0.5217661	total: 30.6ms	remaining: 235ms
# 115:	learn: 0.5209077	total: 30.9ms	remaining: 235ms
# 116:	learn: 0.5201346	total: 31ms	remaining: 234ms
# 117:	learn: 0.5192185	total: 31.3ms	remaining: 234ms
# 118:	learn: 0.5180659	total: 31.6ms	remaining: 234ms
# 119:	learn: 0.5173512	total: 32ms	remaining: 235ms
# 120:	learn: 0.5167930	total: 32.3ms	remaining: 234ms
# 121:	learn: 0.5163844	total: 32.5ms	remaining: 234ms
# 122:	learn: 0.5152960	total: 32.9ms	remaining: 234ms
# 123:	learn: 0.5142604	total: 33.1ms	remaining: 234ms
# 124:	learn: 0.5137372	total: 33.3ms	remaining: 233ms
# 125:	learn: 0.5130147	total: 33.6ms	remaining: 233ms
# 126:	learn: 0.5121699	total: 34ms	remaining: 234ms
# 127:	learn: 0.5113436	total: 34.5ms	remaining: 235ms
# 128:	learn: 0.5103317	total: 34.8ms	remaining: 235ms
# 129:	learn: 0.5097672	total: 35.1ms	remaining: 235ms
# 130:	learn: 0.5088460	total: 35.4ms	remaining: 235ms
# 131:	learn: 0.5080550	total: 35.7ms	remaining: 235ms
# 132:	learn: 0.5071180	total: 35.9ms	remaining: 234ms
# 133:	learn: 0.5065741	total: 36.2ms	remaining: 234ms
# 134:	learn: 0.5055120	total: 36.4ms	remaining: 233ms
# 135:	learn: 0.5047347	total: 36.8ms	remaining: 234ms
# 136:	learn: 0.5038818	total: 37ms	remaining: 233ms
# 137:	learn: 0.5031071	total: 37.1ms	remaining: 232ms
# 138:	learn: 0.5024362	total: 37.3ms	remaining: 231ms
# 139:	learn: 0.5017799	total: 37.6ms	remaining: 231ms
# 140:	learn: 0.5010288	total: 38ms	remaining: 231ms
# 141:	learn: 0.5002329	total: 38.2ms	remaining: 231ms
# 142:	learn: 0.4997131	total: 38.5ms	remaining: 231ms
# 143:	learn: 0.4986777	total: 38.8ms	remaining: 231ms
# 144:	learn: 0.4979392	total: 39.1ms	remaining: 230ms
# 145:	learn: 0.4976737	total: 39.2ms	remaining: 229ms
# 146:	learn: 0.4972105	total: 39.6ms	remaining: 230ms
# 147:	learn: 0.4962931	total: 39.9ms	remaining: 230ms
# 148:	learn: 0.4955410	total: 40.3ms	remaining: 230ms
# 149:	learn: 0.4946835	total: 40.7ms	remaining: 231ms
# 150:	learn: 0.4941363	total: 41ms	remaining: 231ms
# 151:	learn: 0.4934407	total: 41.4ms	remaining: 231ms
# 152:	learn: 0.4929019	total: 41.8ms	remaining: 231ms
# 153:	learn: 0.4921328	total: 42.1ms	remaining: 231ms
# 154:	learn: 0.4913889	total: 42.3ms	remaining: 231ms
# 155:	learn: 0.4906381	total: 42.5ms	remaining: 230ms
# 156:	learn: 0.4899368	total: 42.8ms	remaining: 230ms
# 157:	learn: 0.4892332	total: 43ms	remaining: 229ms
# 158:	learn: 0.4887423	total: 43.3ms	remaining: 229ms
# 159:	learn: 0.4879673	total: 43.6ms	remaining: 229ms
# 160:	learn: 0.4874071	total: 43.9ms	remaining: 229ms
# 161:	learn: 0.4866167	total: 44.1ms	remaining: 228ms
# 162:	learn: 0.4861066	total: 44.4ms	remaining: 228ms
# 163:	learn: 0.4857266	total: 44.7ms	remaining: 228ms
# 164:	learn: 0.4851225	total: 44.9ms	remaining: 227ms
# 165:	learn: 0.4843479	total: 45.1ms	remaining: 227ms
# 166:	learn: 0.4837041	total: 45.4ms	remaining: 227ms
# 167:	learn: 0.4831244	total: 45.7ms	remaining: 226ms
# 168:	learn: 0.4821691	total: 46ms	remaining: 226ms
# 169:	learn: 0.4813747	total: 46.4ms	remaining: 227ms
# 170:	learn: 0.4810539	total: 46.6ms	remaining: 226ms
# 171:	learn: 0.4800239	total: 46.9ms	remaining: 226ms
# 172:	learn: 0.4792371	total: 47.2ms	remaining: 226ms
# 173:	learn: 0.4785674	total: 47.5ms	remaining: 225ms
# 174:	learn: 0.4778342	total: 47.8ms	remaining: 225ms
# 175:	learn: 0.4767207	total: 48ms	remaining: 225ms
# 176:	learn: 0.4762429	total: 48.3ms	remaining: 225ms
# 177:	learn: 0.4756863	total: 48.6ms	remaining: 225ms
# 178:	learn: 0.4753599	total: 48.9ms	remaining: 224ms
# 179:	learn: 0.4745693	total: 49.3ms	remaining: 224ms
# 180:	learn: 0.4739315	total: 49.6ms	remaining: 224ms
# 181:	learn: 0.4732976	total: 49.8ms	remaining: 224ms
# 182:	learn: 0.4728726	total: 50ms	remaining: 223ms
# 183:	learn: 0.4723417	total: 50.2ms	remaining: 223ms
# 184:	learn: 0.4715870	total: 50.4ms	remaining: 222ms
# 185:	learn: 0.4707826	total: 50.8ms	remaining: 222ms
# 186:	learn: 0.4705665	total: 51ms	remaining: 222ms
# 187:	learn: 0.4696105	total: 51.3ms	remaining: 222ms
# 188:	learn: 0.4689313	total: 51.6ms	remaining: 221ms
# 189:	learn: 0.4683009	total: 51.8ms	remaining: 221ms
# 190:	learn: 0.4676392	total: 52.1ms	remaining: 221ms
# 191:	learn: 0.4670224	total: 52.3ms	remaining: 220ms
# 192:	learn: 0.4665209	total: 52.6ms	remaining: 220ms
# 193:	learn: 0.4659796	total: 52.9ms	remaining: 220ms
# 194:	learn: 0.4653754	total: 53.2ms	remaining: 220ms
# 195:	learn: 0.4647397	total: 53.6ms	remaining: 220ms
# 196:	learn: 0.4641708	total: 53.9ms	remaining: 220ms
# 197:	learn: 0.4635379	total: 54.2ms	remaining: 219ms
# 198:	learn: 0.4629467	total: 54.5ms	remaining: 219ms
# 199:	learn: 0.4626217	total: 54.8ms	remaining: 219ms
# 200:	learn: 0.4619886	total: 55.1ms	remaining: 219ms
# 201:	learn: 0.4614501	total: 55.4ms	remaining: 219ms
# 202:	learn: 0.4609307	total: 55.7ms	remaining: 219ms
# 203:	learn: 0.4603485	total: 55.9ms	remaining: 218ms
# 204:	learn: 0.4598971	total: 56.1ms	remaining: 218ms
# 205:	learn: 0.4592659	total: 56.4ms	remaining: 217ms
# 206:	learn: 0.4588291	total: 56.7ms	remaining: 217ms
# 207:	learn: 0.4581942	total: 56.9ms	remaining: 217ms
# 208:	learn: 0.4576914	total: 57.1ms	remaining: 216ms
# 209:	learn: 0.4571476	total: 57.4ms	remaining: 216ms
# 210:	learn: 0.4567323	total: 57.6ms	remaining: 215ms
# 211:	learn: 0.4562481	total: 57.8ms	remaining: 215ms
# 212:	learn: 0.4557887	total: 58.1ms	remaining: 215ms
# 213:	learn: 0.4553687	total: 58.4ms	remaining: 214ms
# 214:	learn: 0.4550033	total: 58.6ms	remaining: 214ms
# 215:	learn: 0.4546564	total: 58.9ms	remaining: 214ms
# 216:	learn: 0.4540019	total: 59.2ms	remaining: 214ms
# 217:	learn: 0.4537291	total: 59.5ms	remaining: 214ms
# 218:	learn: 0.4530121	total: 59.8ms	remaining: 213ms
# 219:	learn: 0.4527127	total: 60.1ms	remaining: 213ms
# 220:	learn: 0.4520413	total: 60.4ms	remaining: 213ms
# 221:	learn: 0.4514576	total: 60.8ms	remaining: 213ms
# 222:	learn: 0.4512717	total: 60.9ms	remaining: 212ms
# 223:	learn: 0.4509616	total: 61.3ms	remaining: 212ms
# 224:	learn: 0.4505635	total: 61.6ms	remaining: 212ms
# 225:	learn: 0.4501238	total: 61.8ms	remaining: 212ms
# 226:	learn: 0.4495662	total: 62.2ms	remaining: 212ms
# 227:	learn: 0.4491547	total: 62.9ms	remaining: 213ms
# 228:	learn: 0.4486726	total: 63.3ms	remaining: 213ms
# 229:	learn: 0.4482631	total: 63.5ms	remaining: 213ms
# 230:	learn: 0.4478842	total: 63.7ms	remaining: 212ms
# 231:	learn: 0.4474211	total: 64ms	remaining: 212ms
# 232:	learn: 0.4469405	total: 64.3ms	remaining: 212ms
# 233:	learn: 0.4464073	total: 64.5ms	remaining: 211ms
# 234:	learn: 0.4460314	total: 64.8ms	remaining: 211ms
# 235:	learn: 0.4456881	total: 65ms	remaining: 210ms
# 236:	learn: 0.4453100	total: 65.3ms	remaining: 210ms
# 237:	learn: 0.4449942	total: 65.5ms	remaining: 210ms
# 238:	learn: 0.4443379	total: 65.8ms	remaining: 210ms
# 239:	learn: 0.4439587	total: 66.1ms	remaining: 209ms
# 240:	learn: 0.4434618	total: 66.3ms	remaining: 209ms
# 241:	learn: 0.4430030	total: 66.5ms	remaining: 208ms
# 242:	learn: 0.4426135	total: 66.8ms	remaining: 208ms
# 243:	learn: 0.4421612	total: 67ms	remaining: 207ms
# 244:	learn: 0.4418175	total: 67.2ms	remaining: 207ms
# 245:	learn: 0.4414376	total: 67.5ms	remaining: 207ms
# 246:	learn: 0.4411007	total: 67.8ms	remaining: 207ms
# 247:	learn: 0.4406459	total: 68ms	remaining: 206ms
# 248:	learn: 0.4402862	total: 68.3ms	remaining: 206ms
# 249:	learn: 0.4398279	total: 68.5ms	remaining: 206ms
# 250:	learn: 0.4394254	total: 68.9ms	remaining: 206ms
# 251:	learn: 0.4390189	total: 69.2ms	remaining: 206ms
# 252:	learn: 0.4383645	total: 69.6ms	remaining: 206ms
# 253:	learn: 0.4378606	total: 69.9ms	remaining: 205ms
# 254:	learn: 0.4375065	total: 70.2ms	remaining: 205ms
# 255:	learn: 0.4370564	total: 70.4ms	remaining: 205ms
# 256:	learn: 0.4365210	total: 70.7ms	remaining: 204ms
# 257:	learn: 0.4358155	total: 71ms	remaining: 204ms
# 258:	learn: 0.4354221	total: 71.3ms	remaining: 204ms
# 259:	learn: 0.4350884	total: 71.5ms	remaining: 204ms
# 260:	learn: 0.4348180	total: 71.8ms	remaining: 203ms
# 261:	learn: 0.4345430	total: 72ms	remaining: 203ms
# 262:	learn: 0.4342599	total: 72.3ms	remaining: 203ms
# 263:	learn: 0.4333403	total: 72.6ms	remaining: 203ms
# 264:	learn: 0.4331073	total: 72.9ms	remaining: 202ms
# 265:	learn: 0.4326303	total: 73.2ms	remaining: 202ms
# 266:	learn: 0.4320195	total: 73.5ms	remaining: 202ms
# 267:	learn: 0.4316389	total: 73.7ms	remaining: 201ms
# 268:	learn: 0.4315017	total: 73.8ms	remaining: 201ms
# 269:	learn: 0.4311778	total: 74.1ms	remaining: 200ms
# 270:	learn: 0.4306463	total: 74.4ms	remaining: 200ms
# 271:	learn: 0.4300902	total: 74.6ms	remaining: 200ms
# 272:	learn: 0.4296726	total: 74.8ms	remaining: 199ms
# 273:	learn: 0.4294040	total: 75.1ms	remaining: 199ms
# 274:	learn: 0.4289232	total: 75.3ms	remaining: 199ms
# 275:	learn: 0.4286699	total: 75.6ms	remaining: 198ms
# 276:	learn: 0.4283439	total: 75.8ms	remaining: 198ms
# 277:	learn: 0.4280367	total: 76ms	remaining: 197ms
# 278:	learn: 0.4277668	total: 76.2ms	remaining: 197ms
# 279:	learn: 0.4273273	total: 76.4ms	remaining: 197ms
# 280:	learn: 0.4270971	total: 76.7ms	remaining: 196ms
# 281:	learn: 0.4266376	total: 77ms	remaining: 196ms
# 282:	learn: 0.4264183	total: 77.2ms	remaining: 196ms
# 283:	learn: 0.4261865	total: 77.5ms	remaining: 195ms
# 284:	learn: 0.4258073	total: 77.7ms	remaining: 195ms
# 285:	learn: 0.4254125	total: 77.9ms	remaining: 195ms
# 286:	learn: 0.4246771	total: 78.2ms	remaining: 194ms
# 287:	learn: 0.4244708	total: 78.4ms	remaining: 194ms
# 288:	learn: 0.4238294	total: 78.7ms	remaining: 194ms
# 289:	learn: 0.4234337	total: 79ms	remaining: 193ms
# 290:	learn: 0.4232107	total: 79.3ms	remaining: 193ms
# 291:	learn: 0.4226372	total: 79.5ms	remaining: 193ms
# 292:	learn: 0.4222101	total: 79.7ms	remaining: 192ms
# 293:	learn: 0.4216787	total: 80ms	remaining: 192ms
# 294:	learn: 0.4213858	total: 80.3ms	remaining: 192ms
# 295:	learn: 0.4210642	total: 80.5ms	remaining: 192ms
# 296:	learn: 0.4208835	total: 80.9ms	remaining: 191ms
# 297:	learn: 0.4204708	total: 81.1ms	remaining: 191ms
# 298:	learn: 0.4202003	total: 81.5ms	remaining: 191ms
# 299:	learn: 0.4196876	total: 81.7ms	remaining: 191ms
# 300:	learn: 0.4194315	total: 82ms	remaining: 191ms
# 301:	learn: 0.4193924	total: 82.2ms	remaining: 190ms
# 302:	learn: 0.4191616	total: 82.5ms	remaining: 190ms
# 303:	learn: 0.4187776	total: 82.8ms	remaining: 190ms
# 304:	learn: 0.4183096	total: 83.2ms	remaining: 190ms
# 305:	learn: 0.4181321	total: 83.6ms	remaining: 190ms
# 306:	learn: 0.4174266	total: 83.9ms	remaining: 189ms
# 307:	learn: 0.4170163	total: 84.2ms	remaining: 189ms
# 308:	learn: 0.4166858	total: 84.6ms	remaining: 189ms
# 309:	learn: 0.4164452	total: 84.8ms	remaining: 189ms
# 310:	learn: 0.4158949	total: 85ms	remaining: 188ms
# 311:	learn: 0.4154713	total: 85.3ms	remaining: 188ms
# 312:	learn: 0.4151200	total: 85.6ms	remaining: 188ms
# 313:	learn: 0.4149721	total: 85.7ms	remaining: 187ms
# 314:	learn: 0.4148475	total: 86ms	remaining: 187ms
# 315:	learn: 0.4146484	total: 86.3ms	remaining: 187ms
# 316:	learn: 0.4142486	total: 86.5ms	remaining: 186ms
# 317:	learn: 0.4141085	total: 86.6ms	remaining: 186ms
# 318:	learn: 0.4139391	total: 87ms	remaining: 186ms
# 319:	learn: 0.4136800	total: 87.3ms	remaining: 186ms
# 320:	learn: 0.4133419	total: 87.5ms	remaining: 185ms
# 321:	learn: 0.4130640	total: 87.8ms	remaining: 185ms
# 322:	learn: 0.4126910	total: 88ms	remaining: 184ms
# 323:	learn: 0.4123373	total: 88.3ms	remaining: 184ms
# 324:	learn: 0.4118701	total: 88.5ms	remaining: 184ms
# 325:	learn: 0.4116645	total: 88.8ms	remaining: 184ms
# 326:	learn: 0.4113868	total: 89.1ms	remaining: 183ms
# 327:	learn: 0.4107911	total: 89.4ms	remaining: 183ms
# 328:	learn: 0.4103054	total: 89.6ms	remaining: 183ms
# 329:	learn: 0.4100756	total: 89.9ms	remaining: 182ms
# 330:	learn: 0.4097421	total: 90.2ms	remaining: 182ms
# 331:	learn: 0.4093646	total: 90.5ms	remaining: 182ms
# 332:	learn: 0.4090616	total: 90.8ms	remaining: 182ms
# 333:	learn: 0.4086430	total: 91.1ms	remaining: 182ms
# 334:	learn: 0.4084943	total: 91.5ms	remaining: 182ms
# 335:	learn: 0.4083163	total: 91.8ms	remaining: 181ms
# 336:	learn: 0.4082075	total: 92ms	remaining: 181ms
# 337:	learn: 0.4079447	total: 92.3ms	remaining: 181ms
# 338:	learn: 0.4077100	total: 92.6ms	remaining: 181ms
# 339:	learn: 0.4074698	total: 92.8ms	remaining: 180ms
# 340:	learn: 0.4072288	total: 93.1ms	remaining: 180ms
# 341:	learn: 0.4070956	total: 93.4ms	remaining: 180ms
# 342:	learn: 0.4068670	total: 93.6ms	remaining: 179ms
# 343:	learn: 0.4064862	total: 94ms	remaining: 179ms
# 344:	learn: 0.4061134	total: 94.1ms	remaining: 179ms
# 345:	learn: 0.4058478	total: 94.3ms	remaining: 178ms
# 346:	learn: 0.4055826	total: 94.6ms	remaining: 178ms
# 347:	learn: 0.4053956	total: 94.7ms	remaining: 177ms
# 348:	learn: 0.4052697	total: 95ms	remaining: 177ms
# 349:	learn: 0.4049818	total: 95.3ms	remaining: 177ms
# 350:	learn: 0.4047953	total: 95.6ms	remaining: 177ms
# 351:	learn: 0.4046004	total: 95.8ms	remaining: 176ms
# 352:	learn: 0.4039354	total: 96.1ms	remaining: 176ms
# 353:	learn: 0.4036419	total: 96.4ms	remaining: 176ms
# 354:	learn: 0.4034063	total: 96.7ms	remaining: 176ms
# 355:	learn: 0.4030526	total: 96.9ms	remaining: 175ms
# 356:	learn: 0.4029170	total: 97.2ms	remaining: 175ms
# 357:	learn: 0.4026208	total: 97.5ms	remaining: 175ms
# 358:	learn: 0.4023986	total: 97.8ms	remaining: 175ms
# 359:	learn: 0.4021169	total: 98ms	remaining: 174ms
# 360:	learn: 0.4018526	total: 98.3ms	remaining: 174ms
# 361:	learn: 0.4015578	total: 98.6ms	remaining: 174ms
# 362:	learn: 0.4010745	total: 98.8ms	remaining: 173ms
# 363:	learn: 0.4009482	total: 98.9ms	remaining: 173ms
# 364:	learn: 0.4004800	total: 99.2ms	remaining: 173ms
# 365:	learn: 0.4003082	total: 99.4ms	remaining: 172ms
# 366:	learn: 0.4000823	total: 99.6ms	remaining: 172ms
# 367:	learn: 0.3999330	total: 99.8ms	remaining: 171ms
# 368:	learn: 0.3995202	total: 100ms	remaining: 171ms
# 369:	learn: 0.3992732	total: 100ms	remaining: 171ms
# 370:	learn: 0.3991235	total: 100ms	remaining: 170ms
# 371:	learn: 0.3988329	total: 101ms	remaining: 170ms
# 372:	learn: 0.3986390	total: 101ms	remaining: 170ms
# 373:	learn: 0.3983309	total: 101ms	remaining: 170ms
# 374:	learn: 0.3981928	total: 102ms	remaining: 169ms
# 375:	learn: 0.3978623	total: 102ms	remaining: 169ms
# 376:	learn: 0.3977060	total: 102ms	remaining: 169ms
# 377:	learn: 0.3974216	total: 102ms	remaining: 168ms
# 378:	learn: 0.3972622	total: 103ms	remaining: 168ms
# 379:	learn: 0.3970176	total: 103ms	remaining: 168ms
# 380:	learn: 0.3968492	total: 103ms	remaining: 167ms
# 381:	learn: 0.3963681	total: 103ms	remaining: 167ms
# 382:	learn: 0.3961639	total: 103ms	remaining: 167ms
# 383:	learn: 0.3959858	total: 104ms	remaining: 166ms
# 384:	learn: 0.3957979	total: 104ms	remaining: 166ms
# 385:	learn: 0.3956067	total: 104ms	remaining: 166ms
# 386:	learn: 0.3954240	total: 105ms	remaining: 166ms
# 387:	learn: 0.3952452	total: 105ms	remaining: 166ms
# 388:	learn: 0.3950067	total: 105ms	remaining: 165ms
# 389:	learn: 0.3945462	total: 106ms	remaining: 165ms
# 390:	learn: 0.3941395	total: 106ms	remaining: 165ms
# 391:	learn: 0.3938126	total: 106ms	remaining: 165ms
# 392:	learn: 0.3935831	total: 107ms	remaining: 165ms
# 393:	learn: 0.3931536	total: 107ms	remaining: 164ms
# 394:	learn: 0.3928764	total: 107ms	remaining: 164ms
# 395:	learn: 0.3927230	total: 107ms	remaining: 164ms
# 396:	learn: 0.3925114	total: 108ms	remaining: 164ms
# 397:	learn: 0.3924976	total: 108ms	remaining: 163ms
# 398:	learn: 0.3921449	total: 108ms	remaining: 163ms
# 399:	learn: 0.3919309	total: 108ms	remaining: 163ms
# 400:	learn: 0.3919131	total: 109ms	remaining: 162ms
# 401:	learn: 0.3916863	total: 109ms	remaining: 162ms
# 402:	learn: 0.3914700	total: 109ms	remaining: 162ms
# 403:	learn: 0.3912004	total: 109ms	remaining: 161ms
# 404:	learn: 0.3909620	total: 110ms	remaining: 161ms
# 405:	learn: 0.3907674	total: 110ms	remaining: 161ms
# 406:	learn: 0.3905811	total: 110ms	remaining: 161ms
# 407:	learn: 0.3902852	total: 111ms	remaining: 161ms
# 408:	learn: 0.3901077	total: 111ms	remaining: 160ms
# 409:	learn: 0.3898731	total: 111ms	remaining: 160ms
# 410:	learn: 0.3896130	total: 112ms	remaining: 160ms
# 411:	learn: 0.3894469	total: 112ms	remaining: 160ms
# 412:	learn: 0.3893007	total: 112ms	remaining: 159ms
# 413:	learn: 0.3892474	total: 112ms	remaining: 159ms
# 414:	learn: 0.3890400	total: 113ms	remaining: 159ms
# 415:	learn: 0.3889345	total: 113ms	remaining: 158ms
# 416:	learn: 0.3887269	total: 113ms	remaining: 158ms
# 417:	learn: 0.3881970	total: 113ms	remaining: 158ms
# 418:	learn: 0.3880742	total: 114ms	remaining: 158ms
# 419:	learn: 0.3878648	total: 114ms	remaining: 157ms
# 420:	learn: 0.3875464	total: 114ms	remaining: 157ms
# 421:	learn: 0.3871856	total: 115ms	remaining: 157ms
# 422:	learn: 0.3869914	total: 115ms	remaining: 157ms
# 423:	learn: 0.3868743	total: 115ms	remaining: 156ms
# 424:	learn: 0.3866961	total: 115ms	remaining: 156ms
# 425:	learn: 0.3864700	total: 116ms	remaining: 156ms
# 426:	learn: 0.3861355	total: 116ms	remaining: 155ms
# 427:	learn: 0.3857733	total: 116ms	remaining: 155ms
# 428:	learn: 0.3856861	total: 117ms	remaining: 155ms
# 429:	learn: 0.3854784	total: 117ms	remaining: 155ms
# 430:	learn: 0.3853428	total: 117ms	remaining: 155ms
# 431:	learn: 0.3851458	total: 118ms	remaining: 155ms
# 432:	learn: 0.3849733	total: 118ms	remaining: 154ms
# 433:	learn: 0.3848520	total: 118ms	remaining: 154ms
# 434:	learn: 0.3844360	total: 118ms	remaining: 154ms
# 435:	learn: 0.3842067	total: 119ms	remaining: 154ms
# 436:	learn: 0.3840529	total: 119ms	remaining: 153ms
# 437:	learn: 0.3838383	total: 119ms	remaining: 153ms
# 438:	learn: 0.3834842	total: 120ms	remaining: 153ms
# 439:	learn: 0.3833233	total: 120ms	remaining: 152ms
# 440:	learn: 0.3831847	total: 120ms	remaining: 152ms
# 441:	learn: 0.3829202	total: 120ms	remaining: 152ms
# 442:	learn: 0.3823471	total: 121ms	remaining: 152ms
# 443:	learn: 0.3820886	total: 121ms	remaining: 152ms
# 444:	learn: 0.3816882	total: 121ms	remaining: 151ms
# 445:	learn: 0.3815208	total: 122ms	remaining: 151ms
# 446:	learn: 0.3813168	total: 122ms	remaining: 151ms
# 447:	learn: 0.3811274	total: 122ms	remaining: 150ms
# 448:	learn: 0.3808984	total: 122ms	remaining: 150ms
# 449:	learn: 0.3807931	total: 123ms	remaining: 150ms
# 450:	learn: 0.3805510	total: 123ms	remaining: 150ms
# 451:	learn: 0.3804029	total: 123ms	remaining: 150ms
# 452:	learn: 0.3803487	total: 124ms	remaining: 149ms
# 453:	learn: 0.3801979	total: 124ms	remaining: 149ms
# 454:	learn: 0.3799848	total: 124ms	remaining: 149ms
# 455:	learn: 0.3798809	total: 124ms	remaining: 148ms
# 456:	learn: 0.3796530	total: 125ms	remaining: 148ms
# 457:	learn: 0.3795485	total: 125ms	remaining: 148ms
# 458:	learn: 0.3794516	total: 125ms	remaining: 147ms
# 459:	learn: 0.3791166	total: 125ms	remaining: 147ms
# 460:	learn: 0.3788994	total: 126ms	remaining: 147ms
# 461:	learn: 0.3786723	total: 126ms	remaining: 147ms
# 462:	learn: 0.3785538	total: 126ms	remaining: 147ms
# 463:	learn: 0.3782265	total: 127ms	remaining: 146ms
# 464:	learn: 0.3779828	total: 127ms	remaining: 146ms
# 465:	learn: 0.3778048	total: 127ms	remaining: 146ms
# 466:	learn: 0.3774783	total: 128ms	remaining: 146ms
# 467:	learn: 0.3773728	total: 128ms	remaining: 145ms
# 468:	learn: 0.3772259	total: 128ms	remaining: 145ms
# 469:	learn: 0.3770086	total: 128ms	remaining: 145ms
# 470:	learn: 0.3769956	total: 128ms	remaining: 144ms
# 471:	learn: 0.3768288	total: 129ms	remaining: 144ms
# 472:	learn: 0.3765942	total: 129ms	remaining: 144ms
# 473:	learn: 0.3764055	total: 129ms	remaining: 143ms
# 474:	learn: 0.3759943	total: 129ms	remaining: 143ms
# 475:	learn: 0.3758487	total: 130ms	remaining: 143ms
# 476:	learn: 0.3756406	total: 130ms	remaining: 143ms
# 477:	learn: 0.3753060	total: 130ms	remaining: 142ms
# 478:	learn: 0.3751285	total: 130ms	remaining: 142ms
# 479:	learn: 0.3750100	total: 131ms	remaining: 142ms
# 480:	learn: 0.3748611	total: 131ms	remaining: 141ms
# 481:	learn: 0.3746319	total: 131ms	remaining: 141ms
# 482:	learn: 0.3745351	total: 132ms	remaining: 141ms
# 483:	learn: 0.3744620	total: 132ms	remaining: 141ms
# 484:	learn: 0.3743866	total: 132ms	remaining: 140ms
# 485:	learn: 0.3741493	total: 133ms	remaining: 140ms
# 486:	learn: 0.3738897	total: 133ms	remaining: 140ms
# 487:	learn: 0.3737912	total: 133ms	remaining: 140ms
# 488:	learn: 0.3735972	total: 133ms	remaining: 139ms
# 489:	learn: 0.3733786	total: 134ms	remaining: 139ms
# 490:	learn: 0.3731255	total: 134ms	remaining: 139ms
# 491:	learn: 0.3728649	total: 134ms	remaining: 139ms
# 492:	learn: 0.3727343	total: 135ms	remaining: 138ms
# 493:	learn: 0.3726705	total: 135ms	remaining: 138ms
# 494:	learn: 0.3725818	total: 135ms	remaining: 138ms
# 495:	learn: 0.3724000	total: 135ms	remaining: 137ms
# 496:	learn: 0.3722340	total: 136ms	remaining: 137ms
# 497:	learn: 0.3719135	total: 136ms	remaining: 137ms
# 498:	learn: 0.3716589	total: 136ms	remaining: 137ms
# 499:	learn: 0.3715182	total: 137ms	remaining: 137ms
# 500:	learn: 0.3714815	total: 137ms	remaining: 136ms
# 501:	learn: 0.3713766	total: 137ms	remaining: 136ms
# 502:	learn: 0.3712343	total: 138ms	remaining: 136ms
# 503:	learn: 0.3710706	total: 138ms	remaining: 136ms
# 504:	learn: 0.3709373	total: 138ms	remaining: 135ms
# 505:	learn: 0.3708511	total: 138ms	remaining: 135ms
# 506:	learn: 0.3706360	total: 139ms	remaining: 135ms
# 507:	learn: 0.3704219	total: 139ms	remaining: 135ms
# 508:	learn: 0.3702242	total: 139ms	remaining: 134ms
# 509:	learn: 0.3700481	total: 139ms	remaining: 134ms
# 510:	learn: 0.3699685	total: 140ms	remaining: 134ms
# 511:	learn: 0.3697867	total: 140ms	remaining: 133ms
# 512:	learn: 0.3695587	total: 140ms	remaining: 133ms
# 513:	learn: 0.3693680	total: 141ms	remaining: 133ms
# 514:	learn: 0.3692388	total: 141ms	remaining: 133ms
# 515:	learn: 0.3689838	total: 141ms	remaining: 132ms
# 516:	learn: 0.3687777	total: 141ms	remaining: 132ms
# 517:	learn: 0.3685490	total: 142ms	remaining: 132ms
# 518:	learn: 0.3683974	total: 142ms	remaining: 132ms
# 519:	learn: 0.3680191	total: 142ms	remaining: 131ms
# 520:	learn: 0.3679401	total: 142ms	remaining: 131ms
# 521:	learn: 0.3678595	total: 143ms	remaining: 131ms
# 522:	learn: 0.3676477	total: 143ms	remaining: 130ms
# 523:	learn: 0.3674954	total: 143ms	remaining: 130ms
# 524:	learn: 0.3674044	total: 143ms	remaining: 130ms
# 525:	learn: 0.3671588	total: 144ms	remaining: 129ms
# 526:	learn: 0.3670469	total: 144ms	remaining: 129ms
# 527:	learn: 0.3669127	total: 144ms	remaining: 129ms
# 528:	learn: 0.3666973	total: 144ms	remaining: 129ms
# 529:	learn: 0.3665874	total: 145ms	remaining: 128ms
# 530:	learn: 0.3665086	total: 145ms	remaining: 128ms
# 531:	learn: 0.3663830	total: 145ms	remaining: 128ms
# 532:	learn: 0.3662172	total: 145ms	remaining: 127ms
# 533:	learn: 0.3659826	total: 146ms	remaining: 127ms
# 534:	learn: 0.3658476	total: 146ms	remaining: 127ms
# 535:	learn: 0.3656088	total: 146ms	remaining: 127ms
# 536:	learn: 0.3654795	total: 146ms	remaining: 126ms
# 537:	learn: 0.3653896	total: 147ms	remaining: 126ms
# 538:	learn: 0.3651883	total: 147ms	remaining: 126ms
# 539:	learn: 0.3647488	total: 147ms	remaining: 125ms
# 540:	learn: 0.3645567	total: 148ms	remaining: 125ms
# 541:	learn: 0.3644759	total: 148ms	remaining: 125ms
# 542:	learn: 0.3642615	total: 148ms	remaining: 125ms
# 543:	learn: 0.3639140	total: 148ms	remaining: 124ms
# 544:	learn: 0.3636506	total: 148ms	remaining: 124ms
# 545:	learn: 0.3634820	total: 149ms	remaining: 124ms
# 546:	learn: 0.3632931	total: 149ms	remaining: 123ms
# 547:	learn: 0.3631793	total: 149ms	remaining: 123ms
# 548:	learn: 0.3630935	total: 149ms	remaining: 123ms
# 549:	learn: 0.3629107	total: 150ms	remaining: 122ms
# 550:	learn: 0.3627765	total: 150ms	remaining: 122ms
# 551:	learn: 0.3625801	total: 150ms	remaining: 122ms
# 552:	learn: 0.3623964	total: 150ms	remaining: 122ms
# 553:	learn: 0.3622609	total: 151ms	remaining: 121ms
# 554:	learn: 0.3620793	total: 151ms	remaining: 121ms
# 555:	learn: 0.3618865	total: 151ms	remaining: 121ms
# 556:	learn: 0.3618190	total: 151ms	remaining: 120ms
# 557:	learn: 0.3615563	total: 151ms	remaining: 120ms
# 558:	learn: 0.3614905	total: 152ms	remaining: 120ms
# 559:	learn: 0.3613134	total: 152ms	remaining: 119ms
# 560:	learn: 0.3612930	total: 152ms	remaining: 119ms
# 561:	learn: 0.3609987	total: 152ms	remaining: 118ms
# 562:	learn: 0.3606971	total: 152ms	remaining: 118ms
# 563:	learn: 0.3605964	total: 153ms	remaining: 118ms
# 564:	learn: 0.3603785	total: 153ms	remaining: 118ms
# 565:	learn: 0.3602045	total: 153ms	remaining: 117ms
# 566:	learn: 0.3601378	total: 153ms	remaining: 117ms
# 567:	learn: 0.3598968	total: 153ms	remaining: 117ms
# 568:	learn: 0.3596664	total: 154ms	remaining: 116ms
# 569:	learn: 0.3593451	total: 154ms	remaining: 116ms
# 570:	learn: 0.3592800	total: 154ms	remaining: 116ms
# 571:	learn: 0.3591848	total: 154ms	remaining: 115ms
# 572:	learn: 0.3589167	total: 154ms	remaining: 115ms
# 573:	learn: 0.3587400	total: 155ms	remaining: 115ms
# 574:	learn: 0.3585326	total: 155ms	remaining: 115ms
# 575:	learn: 0.3583448	total: 155ms	remaining: 114ms
# 576:	learn: 0.3582786	total: 155ms	remaining: 114ms
# 577:	learn: 0.3582372	total: 156ms	remaining: 114ms
# 578:	learn: 0.3580672	total: 157ms	remaining: 114ms
# 579:	learn: 0.3579346	total: 157ms	remaining: 114ms
# 580:	learn: 0.3577040	total: 157ms	remaining: 114ms
# 581:	learn: 0.3576637	total: 158ms	remaining: 113ms
# 582:	learn: 0.3575691	total: 158ms	remaining: 113ms
# 583:	learn: 0.3570578	total: 159ms	remaining: 113ms
# 584:	learn: 0.3568251	total: 159ms	remaining: 113ms
# 585:	learn: 0.3567771	total: 159ms	remaining: 112ms
# 586:	learn: 0.3567050	total: 159ms	remaining: 112ms
# 587:	learn: 0.3564029	total: 160ms	remaining: 112ms
# 588:	learn: 0.3562337	total: 160ms	remaining: 112ms
# 589:	learn: 0.3561367	total: 160ms	remaining: 111ms
# 590:	learn: 0.3557252	total: 161ms	remaining: 111ms
# 591:	learn: 0.3554920	total: 161ms	remaining: 111ms
# 592:	learn: 0.3552410	total: 161ms	remaining: 111ms
# 593:	learn: 0.3551752	total: 162ms	remaining: 110ms
# 594:	learn: 0.3550419	total: 162ms	remaining: 110ms
# 595:	learn: 0.3547857	total: 162ms	remaining: 110ms
# 596:	learn: 0.3546153	total: 162ms	remaining: 110ms
# 597:	learn: 0.3543593	total: 163ms	remaining: 109ms
# 598:	learn: 0.3541700	total: 163ms	remaining: 109ms
# 599:	learn: 0.3540636	total: 163ms	remaining: 109ms
# 600:	learn: 0.3539508	total: 163ms	remaining: 108ms
# 601:	learn: 0.3538035	total: 164ms	remaining: 108ms
# 602:	learn: 0.3536358	total: 164ms	remaining: 108ms
# 603:	learn: 0.3535141	total: 164ms	remaining: 108ms
# 604:	learn: 0.3531803	total: 164ms	remaining: 107ms
# 605:	learn: 0.3531280	total: 165ms	remaining: 107ms
# 606:	learn: 0.3529410	total: 165ms	remaining: 107ms
# 607:	learn: 0.3528216	total: 165ms	remaining: 106ms
# 608:	learn: 0.3526799	total: 165ms	remaining: 106ms
# 609:	learn: 0.3525885	total: 165ms	remaining: 106ms
# 610:	learn: 0.3525391	total: 166ms	remaining: 105ms
# 611:	learn: 0.3521302	total: 166ms	remaining: 105ms
# 612:	learn: 0.3519875	total: 166ms	remaining: 105ms
# 613:	learn: 0.3518953	total: 166ms	remaining: 104ms
# 614:	learn: 0.3516417	total: 166ms	remaining: 104ms
# 615:	learn: 0.3515355	total: 167ms	remaining: 104ms
# 616:	learn: 0.3514768	total: 167ms	remaining: 103ms
# 617:	learn: 0.3513857	total: 167ms	remaining: 103ms
# 618:	learn: 0.3512654	total: 167ms	remaining: 103ms
# 619:	learn: 0.3511693	total: 167ms	remaining: 103ms
# 620:	learn: 0.3509623	total: 168ms	remaining: 102ms
# 621:	learn: 0.3508220	total: 168ms	remaining: 102ms
# 622:	learn: 0.3507717	total: 168ms	remaining: 102ms
# 623:	learn: 0.3505953	total: 169ms	remaining: 102ms
# 624:	learn: 0.3504022	total: 169ms	remaining: 101ms
# 625:	learn: 0.3503007	total: 169ms	remaining: 101ms
# 626:	learn: 0.3500715	total: 169ms	remaining: 101ms
# 627:	learn: 0.3498705	total: 170ms	remaining: 101ms
# 628:	learn: 0.3497269	total: 170ms	remaining: 100ms
# 629:	learn: 0.3495759	total: 170ms	remaining: 100ms
# 630:	learn: 0.3494764	total: 171ms	remaining: 99.8ms
# 631:	learn: 0.3493063	total: 171ms	remaining: 99.6ms
# 632:	learn: 0.3491990	total: 171ms	remaining: 99.4ms
# 633:	learn: 0.3489273	total: 172ms	remaining: 99.1ms
# 634:	learn: 0.3486712	total: 172ms	remaining: 98.8ms
# 635:	learn: 0.3485309	total: 172ms	remaining: 98.6ms
# 636:	learn: 0.3484459	total: 172ms	remaining: 98.3ms
# 637:	learn: 0.3483707	total: 173ms	remaining: 98ms
# 638:	learn: 0.3481790	total: 173ms	remaining: 97.7ms
# 639:	learn: 0.3480742	total: 173ms	remaining: 97.5ms
# 640:	learn: 0.3478394	total: 174ms	remaining: 97.2ms
# 641:	learn: 0.3475167	total: 174ms	remaining: 96.9ms
# 642:	learn: 0.3472982	total: 174ms	remaining: 96.6ms
# 643:	learn: 0.3472090	total: 174ms	remaining: 96.4ms
# 644:	learn: 0.3471141	total: 175ms	remaining: 96.1ms
# 645:	learn: 0.3470102	total: 175ms	remaining: 95.9ms
# 646:	learn: 0.3469155	total: 175ms	remaining: 95.6ms
# 647:	learn: 0.3468470	total: 176ms	remaining: 95.4ms
# 648:	learn: 0.3467009	total: 176ms	remaining: 95.1ms
# 649:	learn: 0.3465872	total: 176ms	remaining: 94.8ms
# 650:	learn: 0.3463999	total: 176ms	remaining: 94.5ms
# 651:	learn: 0.3462352	total: 177ms	remaining: 94.2ms
# 652:	learn: 0.3461660	total: 177ms	remaining: 93.9ms
# 653:	learn: 0.3460354	total: 177ms	remaining: 93.6ms
# 654:	learn: 0.3458726	total: 177ms	remaining: 93.3ms
# 655:	learn: 0.3456734	total: 178ms	remaining: 93.1ms
# 656:	learn: 0.3453056	total: 178ms	remaining: 92.8ms
# 657:	learn: 0.3452474	total: 178ms	remaining: 92.5ms
# 658:	learn: 0.3451357	total: 178ms	remaining: 92.2ms
# 659:	learn: 0.3450247	total: 179ms	remaining: 92ms
# 660:	learn: 0.3449840	total: 179ms	remaining: 91.6ms
# 661:	learn: 0.3448208	total: 179ms	remaining: 91.4ms
# 662:	learn: 0.3445804	total: 180ms	remaining: 91.3ms
# 663:	learn: 0.3444689	total: 180ms	remaining: 91ms
# 664:	learn: 0.3443277	total: 180ms	remaining: 90.7ms
# 665:	learn: 0.3442844	total: 180ms	remaining: 90.4ms
# 666:	learn: 0.3440583	total: 180ms	remaining: 90ms
# 667:	learn: 0.3439920	total: 181ms	remaining: 89.8ms
# 668:	learn: 0.3438749	total: 181ms	remaining: 89.5ms
# 669:	learn: 0.3437044	total: 181ms	remaining: 89.2ms
# 670:	learn: 0.3434900	total: 181ms	remaining: 89ms
# 671:	learn: 0.3433669	total: 182ms	remaining: 88.7ms
# 672:	learn: 0.3431502	total: 182ms	remaining: 88.4ms
# 673:	learn: 0.3430253	total: 182ms	remaining: 88.1ms
# 674:	learn: 0.3428520	total: 182ms	remaining: 87.9ms
# 675:	learn: 0.3425874	total: 183ms	remaining: 87.6ms
# 676:	learn: 0.3423467	total: 183ms	remaining: 87.3ms
# 677:	learn: 0.3421236	total: 184ms	remaining: 87.2ms
# 678:	learn: 0.3420000	total: 184ms	remaining: 86.9ms
# 679:	learn: 0.3419243	total: 184ms	remaining: 86.7ms
# 680:	learn: 0.3417283	total: 184ms	remaining: 86.3ms
# 681:	learn: 0.3415755	total: 185ms	remaining: 86.1ms
# 682:	learn: 0.3414919	total: 185ms	remaining: 85.8ms
# 683:	learn: 0.3414007	total: 185ms	remaining: 85.5ms
# 684:	learn: 0.3412108	total: 185ms	remaining: 85.3ms
# 685:	learn: 0.3410628	total: 186ms	remaining: 85ms
# 686:	learn: 0.3408110	total: 186ms	remaining: 84.8ms
# 687:	learn: 0.3406751	total: 186ms	remaining: 84.4ms
# 688:	learn: 0.3405602	total: 186ms	remaining: 84.2ms
# 689:	learn: 0.3404403	total: 187ms	remaining: 83.9ms
# 690:	learn: 0.3403679	total: 187ms	remaining: 83.7ms
# 691:	learn: 0.3402245	total: 187ms	remaining: 83.4ms
# 692:	learn: 0.3401829	total: 188ms	remaining: 83.2ms
# 693:	learn: 0.3400957	total: 188ms	remaining: 82.9ms
# 694:	learn: 0.3399686	total: 188ms	remaining: 82.7ms
# 695:	learn: 0.3398048	total: 189ms	remaining: 82.4ms
# 696:	learn: 0.3396959	total: 189ms	remaining: 82.1ms
# 697:	learn: 0.3394371	total: 189ms	remaining: 81.9ms
# 698:	learn: 0.3393262	total: 190ms	remaining: 81.6ms
# 699:	learn: 0.3391972	total: 190ms	remaining: 81.3ms
# 700:	learn: 0.3389573	total: 190ms	remaining: 81ms
# 701:	learn: 0.3388554	total: 190ms	remaining: 80.8ms
# 702:	learn: 0.3387454	total: 191ms	remaining: 80.5ms
# 703:	learn: 0.3385344	total: 191ms	remaining: 80.3ms
# 704:	learn: 0.3383208	total: 191ms	remaining: 80ms
# 705:	learn: 0.3382633	total: 192ms	remaining: 79.8ms
# 706:	learn: 0.3380442	total: 192ms	remaining: 79.5ms
# 707:	learn: 0.3378153	total: 192ms	remaining: 79.2ms
# 708:	learn: 0.3376532	total: 192ms	remaining: 78.9ms
# 709:	learn: 0.3375864	total: 193ms	remaining: 78.7ms
# 710:	learn: 0.3374250	total: 193ms	remaining: 78.4ms
# 711:	learn: 0.3373382	total: 193ms	remaining: 78.1ms
# 712:	learn: 0.3373019	total: 193ms	remaining: 77.9ms
# 713:	learn: 0.3372366	total: 194ms	remaining: 77.6ms
# 714:	learn: 0.3370767	total: 194ms	remaining: 77.3ms
# 715:	learn: 0.3368576	total: 194ms	remaining: 77.1ms
# 716:	learn: 0.3367380	total: 195ms	remaining: 76.8ms
# 717:	learn: 0.3363571	total: 195ms	remaining: 76.5ms
# 718:	learn: 0.3361514	total: 195ms	remaining: 76.3ms
# 719:	learn: 0.3360246	total: 195ms	remaining: 76ms
# 720:	learn: 0.3359354	total: 196ms	remaining: 75.7ms
# 721:	learn: 0.3356426	total: 196ms	remaining: 75.4ms
# 722:	learn: 0.3355150	total: 196ms	remaining: 75.2ms
# 723:	learn: 0.3353421	total: 196ms	remaining: 74.9ms
# 724:	learn: 0.3350314	total: 197ms	remaining: 74.6ms
# 725:	learn: 0.3348911	total: 197ms	remaining: 74.4ms
# 726:	learn: 0.3347657	total: 197ms	remaining: 74.1ms
# 727:	learn: 0.3345335	total: 198ms	remaining: 73.8ms
# 728:	learn: 0.3343507	total: 198ms	remaining: 73.6ms
# 729:	learn: 0.3342089	total: 198ms	remaining: 73.3ms
# 730:	learn: 0.3341439	total: 199ms	remaining: 73.1ms
# 731:	learn: 0.3340656	total: 199ms	remaining: 72.8ms
# 732:	learn: 0.3339571	total: 199ms	remaining: 72.5ms
# 733:	learn: 0.3338452	total: 199ms	remaining: 72.2ms
# 734:	learn: 0.3337562	total: 200ms	remaining: 72ms
# 735:	learn: 0.3334912	total: 200ms	remaining: 71.7ms
# 736:	learn: 0.3333704	total: 200ms	remaining: 71.4ms
# 737:	learn: 0.3332370	total: 200ms	remaining: 71.1ms
# 738:	learn: 0.3329143	total: 201ms	remaining: 70.8ms
# 739:	learn: 0.3326595	total: 201ms	remaining: 70.5ms
# 740:	learn: 0.3323423	total: 201ms	remaining: 70.3ms
# 741:	learn: 0.3322347	total: 201ms	remaining: 70ms
# 742:	learn: 0.3321071	total: 202ms	remaining: 69.7ms
# 743:	learn: 0.3319753	total: 202ms	remaining: 69.4ms
# 744:	learn: 0.3319556	total: 202ms	remaining: 69.2ms
# 745:	learn: 0.3318025	total: 202ms	remaining: 68.9ms
# 746:	learn: 0.3316721	total: 203ms	remaining: 68.6ms
# 747:	learn: 0.3316232	total: 203ms	remaining: 68.3ms
# 748:	learn: 0.3314363	total: 203ms	remaining: 68.1ms
# 749:	learn: 0.3313014	total: 203ms	remaining: 67.8ms
# 750:	learn: 0.3311452	total: 204ms	remaining: 67.5ms
# 751:	learn: 0.3310196	total: 204ms	remaining: 67.2ms
# 752:	learn: 0.3309107	total: 204ms	remaining: 66.9ms
# 753:	learn: 0.3308303	total: 204ms	remaining: 66.6ms
# 754:	learn: 0.3307019	total: 204ms	remaining: 66.3ms
# 755:	learn: 0.3306537	total: 205ms	remaining: 66ms
# 756:	learn: 0.3305165	total: 205ms	remaining: 65.7ms
# 757:	learn: 0.3303748	total: 205ms	remaining: 65.5ms
# 758:	learn: 0.3302687	total: 205ms	remaining: 65.2ms
# 759:	learn: 0.3301563	total: 206ms	remaining: 64.9ms
# 760:	learn: 0.3300439	total: 206ms	remaining: 64.6ms
# 761:	learn: 0.3298207	total: 206ms	remaining: 64.4ms
# 762:	learn: 0.3297033	total: 206ms	remaining: 64.1ms
# 763:	learn: 0.3295825	total: 207ms	remaining: 63.8ms
# 764:	learn: 0.3295096	total: 207ms	remaining: 63.6ms
# 765:	learn: 0.3294030	total: 207ms	remaining: 63.3ms
# 766:	learn: 0.3292271	total: 207ms	remaining: 63ms
# 767:	learn: 0.3292068	total: 208ms	remaining: 62.7ms
# 768:	learn: 0.3291364	total: 208ms	remaining: 62.4ms
# 769:	learn: 0.3290044	total: 208ms	remaining: 62.1ms
# 770:	learn: 0.3287455	total: 208ms	remaining: 61.9ms
# 771:	learn: 0.3286891	total: 209ms	remaining: 61.6ms
# 772:	learn: 0.3284979	total: 209ms	remaining: 61.4ms
# 773:	learn: 0.3284870	total: 209ms	remaining: 61.1ms
# 774:	learn: 0.3283563	total: 210ms	remaining: 60.8ms
# 775:	learn: 0.3282713	total: 210ms	remaining: 60.6ms
# 776:	learn: 0.3280760	total: 210ms	remaining: 60.3ms
# 777:	learn: 0.3279759	total: 211ms	remaining: 60.1ms
# 778:	learn: 0.3278334	total: 211ms	remaining: 59.8ms
# 779:	learn: 0.3278110	total: 211ms	remaining: 59.5ms
# 780:	learn: 0.3277256	total: 211ms	remaining: 59.3ms
# 781:	learn: 0.3276265	total: 212ms	remaining: 59ms
# 782:	learn: 0.3274353	total: 212ms	remaining: 58.7ms
# 783:	learn: 0.3272723	total: 212ms	remaining: 58.4ms
# 784:	learn: 0.3271591	total: 212ms	remaining: 58.2ms
# 785:	learn: 0.3268350	total: 213ms	remaining: 57.9ms
# 786:	learn: 0.3266148	total: 213ms	remaining: 57.6ms
# 787:	learn: 0.3264098	total: 213ms	remaining: 57.3ms
# 788:	learn: 0.3262378	total: 213ms	remaining: 57.1ms
# 789:	learn: 0.3259970	total: 214ms	remaining: 56.8ms
# 790:	learn: 0.3258447	total: 214ms	remaining: 56.5ms
# 791:	learn: 0.3254975	total: 214ms	remaining: 56.2ms
# 792:	learn: 0.3252662	total: 214ms	remaining: 56ms
# 793:	learn: 0.3250582	total: 215ms	remaining: 55.7ms
# 794:	learn: 0.3249477	total: 215ms	remaining: 55.4ms
# 795:	learn: 0.3247427	total: 215ms	remaining: 55.2ms
# 796:	learn: 0.3246897	total: 215ms	remaining: 54.9ms
# 797:	learn: 0.3245557	total: 216ms	remaining: 54.6ms
# 798:	learn: 0.3244274	total: 216ms	remaining: 54.3ms
# 799:	learn: 0.3243166	total: 216ms	remaining: 54ms
# 800:	learn: 0.3242162	total: 216ms	remaining: 53.8ms
# 801:	learn: 0.3240744	total: 217ms	remaining: 53.5ms
# 802:	learn: 0.3239464	total: 217ms	remaining: 53.2ms
# 803:	learn: 0.3237446	total: 217ms	remaining: 53ms
# 804:	learn: 0.3235634	total: 217ms	remaining: 52.7ms
# 805:	learn: 0.3234461	total: 218ms	remaining: 52.4ms
# 806:	learn: 0.3233446	total: 218ms	remaining: 52.2ms
# 807:	learn: 0.3233121	total: 219ms	remaining: 51.9ms
# 808:	learn: 0.3230771	total: 219ms	remaining: 51.7ms
# 809:	learn: 0.3229594	total: 219ms	remaining: 51.4ms
# 810:	learn: 0.3227789	total: 219ms	remaining: 51.1ms
# 811:	learn: 0.3226307	total: 220ms	remaining: 50.8ms
# 812:	learn: 0.3225472	total: 220ms	remaining: 50.6ms
# 813:	learn: 0.3223182	total: 220ms	remaining: 50.3ms
# 814:	learn: 0.3222078	total: 221ms	remaining: 50.1ms
# 815:	learn: 0.3220208	total: 221ms	remaining: 49.8ms
# 816:	learn: 0.3219105	total: 221ms	remaining: 49.6ms
# 817:	learn: 0.3218146	total: 222ms	remaining: 49.3ms
# 818:	learn: 0.3215008	total: 222ms	remaining: 49.1ms
# 819:	learn: 0.3213320	total: 222ms	remaining: 48.8ms
# 820:	learn: 0.3212264	total: 223ms	remaining: 48.6ms
# 821:	learn: 0.3210050	total: 223ms	remaining: 48.3ms
# 822:	learn: 0.3207789	total: 223ms	remaining: 48ms
# 823:	learn: 0.3205421	total: 224ms	remaining: 47.8ms
# 824:	learn: 0.3202562	total: 224ms	remaining: 47.5ms
# 825:	learn: 0.3201064	total: 224ms	remaining: 47.2ms
# 826:	learn: 0.3198517	total: 224ms	remaining: 47ms
# 827:	learn: 0.3196243	total: 225ms	remaining: 46.7ms
# 828:	learn: 0.3193664	total: 225ms	remaining: 46.4ms
# 829:	learn: 0.3192894	total: 225ms	remaining: 46.1ms
# 830:	learn: 0.3191575	total: 225ms	remaining: 45.9ms
# 831:	learn: 0.3189046	total: 226ms	remaining: 45.6ms
# 832:	learn: 0.3185139	total: 226ms	remaining: 45.3ms
# 833:	learn: 0.3183623	total: 226ms	remaining: 45ms
# 834:	learn: 0.3179935	total: 226ms	remaining: 44.8ms
# 835:	learn: 0.3179869	total: 227ms	remaining: 44.5ms
# 836:	learn: 0.3176692	total: 227ms	remaining: 44.2ms
# 837:	learn: 0.3175361	total: 227ms	remaining: 43.9ms
# 838:	learn: 0.3174163	total: 227ms	remaining: 43.6ms
# 839:	learn: 0.3173550	total: 228ms	remaining: 43.4ms
# 840:	learn: 0.3172527	total: 228ms	remaining: 43.1ms
# 841:	learn: 0.3172247	total: 228ms	remaining: 42.8ms
# 842:	learn: 0.3171156	total: 228ms	remaining: 42.5ms
# 843:	learn: 0.3169318	total: 228ms	remaining: 42.2ms
# 844:	learn: 0.3166573	total: 229ms	remaining: 42ms
# 845:	learn: 0.3165909	total: 229ms	remaining: 41.7ms
# 846:	learn: 0.3164639	total: 229ms	remaining: 41.4ms
# 847:	learn: 0.3163164	total: 230ms	remaining: 41.2ms
# 848:	learn: 0.3162317	total: 230ms	remaining: 40.9ms
# 849:	learn: 0.3161168	total: 230ms	remaining: 40.6ms
# 850:	learn: 0.3158963	total: 230ms	remaining: 40.4ms
# 851:	learn: 0.3158130	total: 231ms	remaining: 40.1ms
# 852:	learn: 0.3157383	total: 231ms	remaining: 39.8ms
# 853:	learn: 0.3156760	total: 231ms	remaining: 39.5ms
# 854:	learn: 0.3156333	total: 231ms	remaining: 39.3ms
# 855:	learn: 0.3155527	total: 232ms	remaining: 39.1ms
# 856:	learn: 0.3155464	total: 232ms	remaining: 38.8ms
# 857:	learn: 0.3153774	total: 233ms	remaining: 38.5ms
# 858:	learn: 0.3152156	total: 233ms	remaining: 38.2ms
# 859:	learn: 0.3150338	total: 233ms	remaining: 37.9ms
# 860:	learn: 0.3148243	total: 233ms	remaining: 37.6ms
# 861:	learn: 0.3147040	total: 234ms	remaining: 37.4ms
# 862:	learn: 0.3145929	total: 234ms	remaining: 37.1ms
# 863:	learn: 0.3144138	total: 234ms	remaining: 36.9ms
# 864:	learn: 0.3142940	total: 234ms	remaining: 36.6ms
# 865:	learn: 0.3139525	total: 235ms	remaining: 36.3ms
# 866:	learn: 0.3138740	total: 235ms	remaining: 36ms
# 867:	learn: 0.3138128	total: 235ms	remaining: 35.8ms
# 868:	learn: 0.3137021	total: 235ms	remaining: 35.5ms
# 869:	learn: 0.3136291	total: 236ms	remaining: 35.2ms
# 870:	learn: 0.3135522	total: 236ms	remaining: 34.9ms
# 871:	learn: 0.3134086	total: 236ms	remaining: 34.7ms
# 872:	learn: 0.3133252	total: 236ms	remaining: 34.4ms
# 873:	learn: 0.3130095	total: 237ms	remaining: 34.1ms
# 874:	learn: 0.3129512	total: 237ms	remaining: 33.8ms
# 875:	learn: 0.3128089	total: 237ms	remaining: 33.6ms
# 876:	learn: 0.3127214	total: 237ms	remaining: 33.3ms
# 877:	learn: 0.3125348	total: 238ms	remaining: 33ms
# 878:	learn: 0.3123245	total: 238ms	remaining: 32.8ms
# 879:	learn: 0.3120989	total: 238ms	remaining: 32.5ms
# 880:	learn: 0.3119717	total: 239ms	remaining: 32.2ms
# 881:	learn: 0.3118058	total: 239ms	remaining: 31.9ms
# 882:	learn: 0.3117290	total: 239ms	remaining: 31.7ms
# 883:	learn: 0.3116953	total: 239ms	remaining: 31.4ms
# 884:	learn: 0.3114687	total: 240ms	remaining: 31.1ms
# 885:	learn: 0.3113061	total: 240ms	remaining: 30.9ms
# 886:	learn: 0.3113050	total: 240ms	remaining: 30.6ms
# 887:	learn: 0.3112155	total: 240ms	remaining: 30.3ms
# 888:	learn: 0.3110428	total: 241ms	remaining: 30ms
# 889:	learn: 0.3110055	total: 241ms	remaining: 29.8ms
# 890:	learn: 0.3107756	total: 241ms	remaining: 29.5ms
# 891:	learn: 0.3106276	total: 241ms	remaining: 29.2ms
# 892:	learn: 0.3104679	total: 242ms	remaining: 28.9ms
# 893:	learn: 0.3103733	total: 242ms	remaining: 28.7ms
# 894:	learn: 0.3102623	total: 242ms	remaining: 28.4ms
# 895:	learn: 0.3101313	total: 242ms	remaining: 28.1ms
# 896:	learn: 0.3100538	total: 243ms	remaining: 27.9ms
# 897:	learn: 0.3098815	total: 243ms	remaining: 27.6ms
# 898:	learn: 0.3096946	total: 243ms	remaining: 27.3ms
# 899:	learn: 0.3096038	total: 243ms	remaining: 27.1ms
# 900:	learn: 0.3094078	total: 244ms	remaining: 26.8ms
# 901:	learn: 0.3093057	total: 244ms	remaining: 26.5ms
# 902:	learn: 0.3091150	total: 244ms	remaining: 26.2ms
# 903:	learn: 0.3089399	total: 244ms	remaining: 26ms
# 904:	learn: 0.3088248	total: 245ms	remaining: 25.7ms
# 905:	learn: 0.3086302	total: 245ms	remaining: 25.4ms
# 906:	learn: 0.3085417	total: 245ms	remaining: 25.1ms
# 907:	learn: 0.3084509	total: 246ms	remaining: 24.9ms
# 908:	learn: 0.3084455	total: 246ms	remaining: 24.6ms
# 909:	learn: 0.3083892	total: 246ms	remaining: 24.3ms
# 910:	learn: 0.3082965	total: 246ms	remaining: 24.1ms
# 911:	learn: 0.3081010	total: 246ms	remaining: 23.8ms
# 912:	learn: 0.3078147	total: 247ms	remaining: 23.5ms
# 913:	learn: 0.3074961	total: 247ms	remaining: 23.3ms
# 914:	learn: 0.3074577	total: 248ms	remaining: 23ms
# 915:	learn: 0.3072940	total: 249ms	remaining: 22.8ms
# 916:	learn: 0.3072692	total: 249ms	remaining: 22.5ms
# 917:	learn: 0.3071496	total: 249ms	remaining: 22.2ms
# 918:	learn: 0.3069269	total: 249ms	remaining: 22ms
# 919:	learn: 0.3067169	total: 249ms	remaining: 21.7ms
# 920:	learn: 0.3065606	total: 250ms	remaining: 21.4ms
# 921:	learn: 0.3062452	total: 250ms	remaining: 21.1ms
# 922:	learn: 0.3060934	total: 250ms	remaining: 20.9ms
# 923:	learn: 0.3060375	total: 250ms	remaining: 20.6ms
# 924:	learn: 0.3057385	total: 250ms	remaining: 20.3ms
# 925:	learn: 0.3055862	total: 251ms	remaining: 20ms
# 926:	learn: 0.3054847	total: 251ms	remaining: 19.8ms
# 927:	learn: 0.3051018	total: 251ms	remaining: 19.5ms
# 928:	learn: 0.3049468	total: 251ms	remaining: 19.2ms
# 929:	learn: 0.3049060	total: 252ms	remaining: 19ms
# 930:	learn: 0.3047797	total: 252ms	remaining: 18.7ms
# 931:	learn: 0.3045598	total: 252ms	remaining: 18.4ms
# 932:	learn: 0.3044307	total: 253ms	remaining: 18.1ms
# 933:	learn: 0.3043866	total: 253ms	remaining: 17.9ms
# 934:	learn: 0.3042002	total: 253ms	remaining: 17.6ms
# 935:	learn: 0.3040948	total: 254ms	remaining: 17.3ms
# 936:	learn: 0.3039273	total: 254ms	remaining: 17.1ms
# 937:	learn: 0.3037995	total: 254ms	remaining: 16.8ms
# 938:	learn: 0.3037040	total: 254ms	remaining: 16.5ms
# 939:	learn: 0.3035923	total: 255ms	remaining: 16.3ms
# 940:	learn: 0.3034522	total: 255ms	remaining: 16ms
# 941:	learn: 0.3034179	total: 255ms	remaining: 15.7ms
# 942:	learn: 0.3032570	total: 256ms	remaining: 15.4ms
# 943:	learn: 0.3030414	total: 256ms	remaining: 15.2ms
# 944:	learn: 0.3029213	total: 256ms	remaining: 14.9ms
# 945:	learn: 0.3027354	total: 256ms	remaining: 14.6ms
# 946:	learn: 0.3027149	total: 256ms	remaining: 14.4ms
# 947:	learn: 0.3025872	total: 257ms	remaining: 14.1ms
# 948:	learn: 0.3024062	total: 257ms	remaining: 13.8ms
# 949:	learn: 0.3022583	total: 257ms	remaining: 13.5ms
# 950:	learn: 0.3020143	total: 258ms	remaining: 13.3ms
# 951:	learn: 0.3019834	total: 258ms	remaining: 13ms
# 952:	learn: 0.3018044	total: 258ms	remaining: 12.7ms
# 953:	learn: 0.3016326	total: 259ms	remaining: 12.5ms
# 954:	learn: 0.3015541	total: 259ms	remaining: 12.2ms
# 955:	learn: 0.3014357	total: 259ms	remaining: 11.9ms
# 956:	learn: 0.3013903	total: 259ms	remaining: 11.6ms
# 957:	learn: 0.3011144	total: 259ms	remaining: 11.4ms
# 958:	learn: 0.3010220	total: 260ms	remaining: 11.1ms
# 959:	learn: 0.3008891	total: 260ms	remaining: 10.8ms
# 960:	learn: 0.3007962	total: 260ms	remaining: 10.6ms
# 961:	learn: 0.3006906	total: 260ms	remaining: 10.3ms
# 962:	learn: 0.3005747	total: 261ms	remaining: 10ms
# 963:	learn: 0.3005220	total: 261ms	remaining: 9.74ms
# 964:	learn: 0.3003909	total: 261ms	remaining: 9.47ms
# 965:	learn: 0.3003845	total: 261ms	remaining: 9.19ms
# 966:	learn: 0.3002807	total: 261ms	remaining: 8.92ms
# 967:	learn: 0.3001730	total: 262ms	remaining: 8.65ms
# 968:	learn: 0.3000233	total: 262ms	remaining: 8.38ms
# 969:	learn: 0.2999165	total: 262ms	remaining: 8.1ms
# 970:	learn: 0.2997876	total: 262ms	remaining: 7.83ms
# 971:	learn: 0.2995001	total: 263ms	remaining: 7.56ms
# 972:	learn: 0.2994068	total: 263ms	remaining: 7.29ms
# 973:	learn: 0.2992954	total: 263ms	remaining: 7.02ms
# 974:	learn: 0.2992208	total: 263ms	remaining: 6.75ms
# 975:	learn: 0.2990235	total: 264ms	remaining: 6.48ms
# 976:	learn: 0.2988464	total: 264ms	remaining: 6.21ms
# 977:	learn: 0.2986316	total: 264ms	remaining: 5.94ms
# 978:	learn: 0.2984360	total: 264ms	remaining: 5.67ms
# 979:	learn: 0.2982892	total: 264ms	remaining: 5.4ms
# 980:	learn: 0.2981236	total: 265ms	remaining: 5.13ms
# 981:	learn: 0.2979323	total: 265ms	remaining: 4.86ms
# 982:	learn: 0.2977743	total: 265ms	remaining: 4.59ms
# 983:	learn: 0.2976137	total: 266ms	remaining: 4.32ms
# 984:	learn: 0.2972513	total: 266ms	remaining: 4.05ms
# 985:	learn: 0.2971183	total: 266ms	remaining: 3.78ms
# 986:	learn: 0.2969994	total: 266ms	remaining: 3.51ms
# 987:	learn: 0.2968500	total: 267ms	remaining: 3.24ms
# 988:	learn: 0.2967064	total: 267ms	remaining: 2.97ms
# 989:	learn: 0.2966407	total: 267ms	remaining: 2.7ms
# 990:	learn: 0.2964274	total: 268ms	remaining: 2.43ms
# 991:	learn: 0.2962137	total: 268ms	remaining: 2.16ms
# 992:	learn: 0.2961105	total: 268ms	remaining: 1.89ms
# 993:	learn: 0.2960503	total: 268ms	remaining: 1.62ms
# 994:	learn: 0.2958714	total: 269ms	remaining: 1.35ms
# 995:	learn: 0.2957365	total: 269ms	remaining: 1.08ms
# 996:	learn: 0.2955660	total: 269ms	remaining: 809us
# 997:	learn: 0.2955393	total: 269ms	remaining: 539us
# 998:	learn: 0.2953723	total: 270ms	remaining: 269us
# 999:	learn: 0.2952295	total: 270ms	remaining: 0us

# %%
print(Fore.GREEN + "Accuracy of CatBoostClassifier is : ","{:.2f}%".format(100* cat_acc))
# Out:
# Accuracy of CatBoostClassifier is :  76.67%

# %%
cm = confusion_matrix(y_test, cat_pred)
plt.figure()
plot_confusion_matrix(cm, figsize=(5,5), hide_ticks=True, cmap=plt.cm.Blues)
plt.title("Cat Boost Classifier Model - Confusion Matrix")
plt.xticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
plt.yticks(range(2), ["Heart Not Failed","Heart Fail"], fontsize=16)
plt.show()

# %%
model_list = ['Logistic Regression', 'SVC','KNearestNeighbours', 'DecisionTree', 'RandomForest',
              'GradientBooster', 'XGBRF','LGBM', 'CatBoostClassifier']

# %%
import seaborn as sns

plt.rcParams['figure.figsize']=(20,8)
sns.set_style('darkgrid')
ax = sns.barplot(x=model_list, y=accuracy_list, palette = "husl", saturation =2.0)
plt.xlabel('Classifier Models', fontsize = 20 )
plt.ylabel('% of Accuracy', fontsize = 20)
plt.title('Accuracy of different Classifier Models', fontsize = 20)
plt.xticks(fontsize = 12, horizontalalignment = 'center', rotation = 8)
plt.yticks(fontsize = 12)
for i in ax.patches:
    width, height = i.get_width(), i.get_height()
    x, y = i.get_xy() 
    ax.annotate(f'{round(height,2)}%', (x + width/2, y + height*1.02), ha='center', fontsize = 'x-large')
plt.show()
