# %% [markdown]
# # How is the President of the United States elected?
# [Reference1](https://www.kaggle.com/datasets/unanimad/us-election-2020?datasetId=955555&sortBy=voteCount)
# [Reference2](https://www.kaggle.com/datasets/muonneutrino/us-census-demographic-data)

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ## EDA

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
# from US Election 2020
df_pres = pd.read_csv('./president_county_candidate.csv')
df_gov = pd.read_csv('./governors_county_candidate.csv')

# from US Census 2017
df_census = pd.read_csv('./acs2017_county_data.csv')

# State Code 관련 부가자료
state_code1 = pd.read_html('https://www.infoplease.com/us/postal-information/state-abbreviations-and-state-postal-codes')[0]
state_code2 = pd.read_html('https://www.infoplease.com/us/postal-information/state-abbreviations-and-state-postal-codes')[1]

# %%
df_pres.head()
# Out:
#       state             county      candidate party  total_votes    won
# 0  Delaware        Kent County      Joe Biden   DEM        44552   True
# 1  Delaware        Kent County   Donald Trump   REP        41009  False
# 2  Delaware        Kent County   Jo Jorgensen   LIB         1044  False
# 3  Delaware        Kent County  Howie Hawkins   GRN          420  False
# 4  Delaware  New Castle County      Joe Biden   DEM       195034   True

# %%
df_pres['candidate'].unique()
# Out:
# array(['Joe Biden', 'Donald Trump', 'Jo Jorgensen', 'Howie Hawkins',
#        ' Write-ins', 'Gloria La Riva', 'Brock Pierce',
#        'Rocky De La Fuente', 'Don Blankenship', 'Kanye West',
#        'Brian Carroll', 'Ricki Sue King', 'Jade Simmons',
#        'President Boddie', 'Bill Hammons', 'Tom Hoefling',
#        'Alyson Kennedy', 'Jerome Segal', 'Phil Collins',
#        ' None of these candidates', 'Sheila Samm Tittle', 'Dario Hunter',
#        'Joe McHugh', 'Christopher LaFontaine', 'Keith McCormic',
#        'Brooke Paige', 'Gary Swing', 'Richard Duncan', 'Blake Huber',
#        'Kyle Kopitke', 'Zachary Scalf', 'Jesse Ventura', 'Connie Gammon',
#        'John Richard Myers', 'Mark Charles', 'Princess Jacob-Fambro',
#        'Joseph Kishore', 'Jordan Scott'], dtype=object)

# %%
df_pres['candidate'].value_counts()
# Out:
# Joe Biden                    4633
# Donald Trump                 4633
# Jo Jorgensen                 4633
#  Write-ins                   3792
# Howie Hawkins                2994
# Rocky De La Fuente           1562
# Don Blankenship              1317
# Brock Pierce                 1124
# Kanye West                   1082
# Gloria La Riva               1028
# Brian Carroll                 745
# Alyson Kennedy                595
# Phil Collins                  467
# Kyle Kopitke                  310
# Blake Huber                   310
# Jerome Segal                  270
# Gary Swing                    246
# Zachary Scalf                 246
# Richard Duncan                246
# Christopher LaFontaine        246
# Keith McCormic                246
# Brooke Paige                  246
# Bill Hammons                  149
# Jade Simmons                  141
# Dario Hunter                  100
# Ricki Sue King                 99
# Joe McHugh                     93
# Connie Gammon                  75
# John Richard Myers             75
# Joseph Kishore                 64
# Mark Charles                   64
# Princess Jacob-Fambro          64
# Jordan Scott                   64
# Tom Hoefling                   64
# President Boddie               64
# Jesse Ventura                  40
# Sheila Samm Tittle             33
#  None of these candidates      17
# Name: candidate, dtype: int64

# %% [markdown]
# $\rightarrow \textbf{Write-ins:}\; \text{직접 와서 이름을 적은 횟수}$

# %%
df_pres.loc[df_pres['candidate'] == 'Kanye West']['total_votes'].sum()
# Out:
# 66367

# %%
df_pres.loc[df_pres['candidate'] == 'Joe Biden']['total_votes'].sum()
# Out:
# 82046434

# %% [markdown]
# $\rightarrow \textbf{Kanye West와 Joe Biden 사이의 투표수 비교}$

# %%
print(len(df_pres['state'].unique()))
print(df_pres['state'].unique())
# Out:
# 51
# ['Delaware' 'District of Columbia' 'Florida' 'Georgia' 'Hawaii' 'Idaho'
#  'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine'
#  'Maryland' 'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi'
#  'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey'
#  'New Mexico' 'New York' 'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma'
#  'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina' 'South Dakota'
#  'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia' 'Washington'
#  'West Virginia' 'Wisconsin' 'Wyoming' 'Alabama' 'Alaska' 'Arkansas'
#  'California' 'Colorado' 'Connecticut' 'Arizona']

# %% [markdown]
# $\rightarrow \textbf{df_pres의 state 개수}$

# %%
df_gov
# Out:
#               state             county        candidate party   votes    won
# 0          Delaware        Kent County      John Carney   DEM   44352   True
# 1          Delaware        Kent County  Julianne Murray   REP   39332  False
# 2          Delaware        Kent County  Kathy DeMatteis   IPD    1115  False
# 3          Delaware        Kent County    John Machurek   LIB     616  False
# 4          Delaware  New Castle County      John Carney   DEM  191678   True
# ...             ...                ...              ...   ...     ...    ...
# 5140  West Virginia     Wyoming County      Jim Justice   REP    6941   True
# 5141  West Virginia     Wyoming County      Ben Salango   DEM    1240  False
# 5142  West Virginia     Wyoming County   Erika Kolenich   LIB      86  False
# 5143  West Virginia     Wyoming County       Danny Lutz   MNP      53  False
# 5144  West Virginia     Wyoming County        Write-ins   WRI       0  False
#
# [5145 rows x 6 columns]

# %%
print(len(df_gov['state'].unique()))
print(df_gov['state'].unique())
# Out:
# 11
# ['Delaware' 'Indiana' 'Missouri' 'Montana' 'New Hampshire'
#  'North Carolina' 'North Dakota' 'Utah' 'Vermont' 'Washington'
#  'West Virginia']

# %% [markdown]
# $\rightarrow \textbf{df_gov의 state 개수}$

# %%
print(len(df_census['State'].unique()))
print(df_census['State'].unique())
# Out:
# 52
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'District of Columbia' 'Florida' 'Georgia'
#  'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky'
#  'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan' 'Minnesota'
#  'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire'
#  'New Jersey' 'New Mexico' 'New York' 'North Carolina' 'North Dakota'
#  'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina'
#  'South Dakota' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Wyoming' 'Puerto Rico']

# %%
len(state_code1['State Name/District'].unique())
# Out:
# 51

# %%
len(state_code2['Territory/Associate'].unique())
# Out:
# 8

# %%
census_state = df_census['State'].unique()
state_code = state_code1['State Name/District'].unique()
for state in census_state:
    if state in state_code:
        pass
    else:
        print(state)
# Out:
# Puerto Rico

# %%
pres_state = df_pres['state'].unique()
state_code = state_code1['State Name/District'].unique()
for state in pres_state:
    if state in state_code:
        pass
    else:
        print(state)

# %% [markdown]
# $\rightarrow \textbf{df_pres['state']값은 모두 일치함}$

# %%
df_census['County'].value_counts()
# Out:
# Washington County    30
# Jefferson County     25
# Franklin County      24
# Jackson County       23
# Lincoln County       23
#                      ..
# Nantucket County      1
# Hampden County        1
# Dukes County          1
# Berkshire County      1
# Yauco Municipio       1
# Name: County, Length: 1955, dtype: int64

# %%
df_census.drop(index = df_census[df_census['State']=='Puerto Rico'].index, inplace=True)

# %%
len(df_census['State'].unique())
# Out:
# 51

# %%
data1 = df_pres.loc[df_pres['party'].apply(lambda s: str(s) in ['DEM', 'REP'])]
pd.pivot_table(data=data1, index=['state','county'], columns='party', values='total_votes')
# Out:
# party                        DEM    REP
# state   county
# Alabama Autauga County      7503  19838
#         Baldwin County     24578  83544
#         Barbour County      4816   5622
#         Bibb County         1986   7525
#         Blount County       2640  24711
# ...                          ...    ...
# Wyoming Sweetwater County   3823  12229
#         Teton County        9848   4341
#         Uinta County        1591   7496
#         Washakie County      651   3245
#         Weston County        360   3107
#
# [4633 rows x 2 columns]

# %%
data1 = df_pres.loc[df_pres['party'].apply(lambda s: str(s) in ['DEM', 'REP'])]
table_pres = pd.pivot_table(data=data1, index=['state', 'county'], columns='party', values='total_votes')
table_pres.rename({'DEM':'Pres_DEM','REP':'Pres_REP'}, axis=1, inplace=True)
print(table_pres.isna().sum())
table_pres
# Out:
# party
# Pres_DEM    0
# Pres_REP    0
# dtype: int64
# party                      Pres_DEM  Pres_REP
# state   county
# Alabama Autauga County         7503     19838
#         Baldwin County        24578     83544
#         Barbour County         4816      5622
#         Bibb County            1986      7525
#         Blount County          2640     24711
# ...                             ...       ...
# Wyoming Sweetwater County      3823     12229
#         Teton County           9848      4341
#         Uinta County           1591      7496
#         Washakie County         651      3245
#         Weston County           360      3107
#
# [4633 rows x 2 columns]

# %%
data1.head(10)
# Out:
#                    state                county     candidate party  \
# 0               Delaware           Kent County     Joe Biden   DEM
# 1               Delaware           Kent County  Donald Trump   REP
# 4               Delaware     New Castle County     Joe Biden   DEM
# 5               Delaware     New Castle County  Donald Trump   REP
# 8               Delaware         Sussex County  Donald Trump   REP
# 9               Delaware         Sussex County     Joe Biden   DEM
# 12  District of Columbia  District of Columbia     Joe Biden   DEM
# 13  District of Columbia  District of Columbia  Donald Trump   REP
# 19  District of Columbia                Ward 2     Joe Biden   DEM
# 20  District of Columbia                Ward 2  Donald Trump   REP
#
#     total_votes    won
# 0         44552   True
# 1         41009  False
# 4        195034   True
# 5         88364  False
# 8         71230   True
# 9         56682  False
# 12        39041   True
# 13         1725  False
# 19        29078   True
# 20         2918  False

# %%
df_gov.head()
# Out:
#       state             county        candidate party   votes    won
# 0  Delaware        Kent County      John Carney   DEM   44352   True
# 1  Delaware        Kent County  Julianne Murray   REP   39332  False
# 2  Delaware        Kent County  Kathy DeMatteis   IPD    1115  False
# 3  Delaware        Kent County    John Machurek   LIB     616  False
# 4  Delaware  New Castle County      John Carney   DEM  191678   True

# %%
data2 = df_gov.loc[df_gov['party'].apply(lambda s: str(s) in ['DEM', 'REP'])]
table_gov = pd.pivot_table(data=data2, index=['state', 'county'], columns='party', values='votes')
table_gov.rename({'DEM':'Gov_DEM','REP':'Gov_REP'}, axis=1, inplace=True)
print(table_gov.isna().sum())
table_gov
# Out:
# party
# Gov_DEM    0
# Gov_REP    0
# dtype: int64
# party                            Gov_DEM  Gov_REP
# state         county
# Delaware      Kent County          44352    39332
#               New Castle County   191678    82545
#               Sussex County        56873    68435
# Indiana       Adams County          2143     9441
#               Allen County         53895    98406
# ...                                  ...      ...
# West Virginia Webster County         659     2552
#               Wetzel County         1727     4559
#               Wirt County            483     1947
#               Wood County           9933    26232
#               Wyoming County        1240     6941
#
# [1025 rows x 2 columns]

# %%
df_census.rename({'State':'state','County':'county'}, axis=1, inplace=True)
df_census.drop('CountyId',axis=1, inplace=True)
df_census.set_index(['state','county'], inplace=True)
df_census
# Out:
#                            TotalPop    Men   Women  Hispanic  White  Black  \
# state   county
# Alabama Autauga County        55036  26899   28137       2.7   75.4   18.9
#         Baldwin County       203360  99527  103833       4.4   83.1    9.5
#         Barbour County        26201  13976   12225       4.2   45.7   47.8
#         Bibb County           22580  12251   10329       2.4   74.6   22.0
#         Blount County         57667  28490   29177       9.0   87.4    1.5
# ...                             ...    ...     ...       ...    ...    ...
# Wyoming Sweetwater County     44527  22981   21546      16.0   79.6    0.8
#         Teton County          22923  12169   10754      15.0   81.5    0.5
#         Uinta County          20758  10593   10165       9.1   87.7    0.1
#         Washakie County        8253   4118    4135      14.2   82.2    0.3
#         Weston County          7117   3756    3361       1.4   91.6    0.5
#
#                            Native  Asian  Pacific  VotingAgeCitizen  ...  \
# state   county                                                       ...
# Alabama Autauga County        0.3    0.9      0.0             41016  ...
#         Baldwin County        0.8    0.7      0.0            155376  ...
#         Barbour County        0.2    0.6      0.0             20269  ...
#         Bibb County           0.4    0.0      0.0             17662  ...
#         Blount County         0.3    0.1      0.0             42513  ...
# ...                           ...    ...      ...               ...  ...
# Wyoming Sweetwater County     0.6    0.6      0.5             31025  ...
#         Teton County          0.3    2.2      0.0             16692  ...
#         Uinta County          0.9    0.1      0.0             14235  ...
#         Washakie County       0.4    0.1      0.0              6125  ...
#         Weston County         0.1    4.3      0.0              5510  ...
#
#                            Walk  OtherTransp  WorkAtHome  MeanCommute  \
# state   county
# Alabama Autauga County      0.6          1.3         2.5         25.8
#         Baldwin County      0.8          1.1         5.6         27.0
#         Barbour County      2.2          1.7         1.3         23.4
#         Bibb County         0.3          1.7         1.5         30.0
#         Blount County       0.4          0.4         2.1         35.0
# ...                         ...          ...         ...          ...
# Wyoming Sweetwater County   2.8          1.3         1.5         20.5
#         Teton County       11.7          3.8         5.7         14.3
#         Uinta County        1.1          1.3         2.0         19.9
#         Washakie County     6.9          1.3         4.4         14.3
#         Weston County       3.0          1.6         6.9         25.7
#
#                            Employed  PrivateWork  PublicWork  SelfEmployed  \
# state   county
# Alabama Autauga County        24112         74.1        20.2           5.6
#         Baldwin County        89527         80.7        12.9           6.3
#         Barbour County         8878         74.1        19.1           6.5
#         Bibb County            8171         76.0        17.4           6.3
#         Blount County         21380         83.9        11.9           4.0
# ...                             ...          ...         ...           ...
# Wyoming Sweetwater County     22739         78.4        17.8           3.8
#         Teton County          14492         82.1        11.4           6.5
#         Uinta County           9528         71.5        21.5           6.6
#         Washakie County        3833         69.8        22.0           8.1
#         Weston County          3407         68.2        21.9           8.8
#
#                            FamilyWork  Unemployment
# state   county
# Alabama Autauga County            0.1           5.2
#         Baldwin County            0.1           5.5
#         Barbour County            0.3          12.4
#         Bibb County               0.3           8.2
#         Blount County             0.1           4.9
# ...                               ...           ...
# Wyoming Sweetwater County         0.0           5.2
#         Teton County              0.0           1.3
#         Uinta County              0.4           6.4
#         Washakie County           0.2           6.1
#         Weston County             1.1           2.2
#
# [3142 rows x 34 columns]

# %%
df_census.columns
# Out:
# Index(['TotalPop', 'Men', 'Women', 'Hispanic', 'White', 'Black', 'Native',
#        'Asian', 'Pacific', 'VotingAgeCitizen', 'Income', 'IncomeErr',
#        'IncomePerCap', 'IncomePerCapErr', 'Poverty', 'ChildPoverty',
#        'Professional', 'Service', 'Office', 'Construction', 'Production',
#        'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome',
#        'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed',
#        'FamilyWork', 'Unemployment'],
#       dtype='object')

# %%
# 불필요한 데이터 Drop
df_census.drop(['Income', 'IncomeErr', 'IncomePerCapErr'], axis=1, inplace=True)

# %%
# Multi-Colinearity를 피하기 위해 '전체인구','남자','여자' -> '남자비율'
df_census.drop(['Women'], axis=1, inplace=True)
df_census['Men'] /= df_census['TotalPop']
df_census['VotingAgeCitizen'] /= df_census['TotalPop']
df_census['Employed'] /= df_census['TotalPop']

# %%
df_census.head(-10)
# Out:
#                             TotalPop       Men  Hispanic  White  Black  \
# state   county
# Alabama Autauga County         55036  0.488753       2.7   75.4   18.9
#         Baldwin County        203360  0.489413       4.4   83.1    9.5
#         Barbour County         26201  0.533415       4.2   45.7   47.8
#         Bibb County            22580  0.542560       2.4   74.6   22.0
#         Blount County          57667  0.494043       9.0   87.4    1.5
# ...                              ...       ...       ...    ...    ...
# Wyoming Hot Springs County      4741  0.507066       1.9   94.5    0.0
#         Johnson County          8562  0.531184       2.1   91.7    1.4
#         Laramie County         97031  0.507240      14.3   79.1    2.6
#         Lincoln County         18791  0.512479       4.5   92.5    0.3
#         Natrona County         81023  0.506782       8.2   87.0    1.2
#
#                             Native  Asian  Pacific  VotingAgeCitizen  \
# state   county
# Alabama Autauga County         0.3    0.9      0.0          0.745258
#         Baldwin County         0.8    0.7      0.0          0.764044
#         Barbour County         0.2    0.6      0.0          0.773596
#         Bibb County            0.4    0.0      0.0          0.782197
#         Blount County          0.3    0.1      0.0          0.737215
# ...                            ...    ...      ...               ...
# Wyoming Hot Springs County     2.3    0.0      0.0          0.796667
#         Johnson County         2.7    0.0      0.0          0.767928
#         Laramie County         0.8    1.1      0.1          0.751296
#         Lincoln County         0.3    0.3      0.0          0.713054
#         Natrona County         0.6    0.8      0.0          0.742962
#
#                             IncomePerCap  ...  Walk  OtherTransp  WorkAtHome  \
# state   county                            ...
# Alabama Autauga County             27824  ...   0.6          1.3         2.5
#         Baldwin County             29364  ...   0.8          1.1         5.6
#         Barbour County             17561  ...   2.2          1.7         1.3
#         Bibb County                20911  ...   0.3          1.7         1.5
#         Blount County              22021  ...   0.4          0.4         2.1
# ...                                  ...  ...   ...          ...         ...
# Wyoming Hot Springs County         30939  ...   7.8          0.5         7.2
#         Johnson County             32732  ...   1.9          2.8         7.7
#         Laramie County             31554  ...   2.6          1.5         3.8
#         Lincoln County             29516  ...   2.5          1.5         4.5
#         Natrona County             31900  ...   1.6          1.1         3.6
#
#                             MeanCommute  Employed  PrivateWork  PublicWork  \
# state   county
# Alabama Autauga County             25.8  0.438113         74.1        20.2
#         Baldwin County             27.0  0.440239         80.7        12.9
#         Barbour County             23.4  0.338842         74.1        19.1
#         Bibb County                30.0  0.361869         76.0        17.4
#         Blount County              35.0  0.370749         83.9        11.9
# ...                                 ...       ...          ...         ...
# Wyoming Hot Springs County         19.6  0.483020         68.2        21.3
#         Johnson County             24.6  0.498365         64.9        21.5
#         Laramie County             15.8  0.486886         68.2        26.2
#         Lincoln County             26.2  0.485552         73.9        18.2
#         Natrona County             17.2  0.511793         79.3        14.7
#
#                             SelfEmployed  FamilyWork  Unemployment
# state   county
# Alabama Autauga County               5.6         0.1           5.2
#         Baldwin County               6.3         0.1           5.5
#         Barbour County               6.5         0.3          12.4
#         Bibb County                  6.3         0.3           8.2
#         Blount County                4.0         0.1           4.9
# ...                                  ...         ...           ...
# Wyoming Hot Springs County          10.0         0.5           4.1
#         Johnson County              11.6         2.0           4.3
#         Laramie County               5.3         0.3           5.3
#         Lincoln County               7.6         0.3           6.0
#         Natrona County               5.6         0.4           5.1
#
# [3132 rows x 30 columns]

# %%
df = pd.concat([table_pres, table_gov, df_census], axis=1)
df
# Out:
#                            Pres_DEM  Pres_REP  Gov_DEM  Gov_REP  TotalPop  \
# state   county
# Alabama Autauga County       7503.0   19838.0      NaN      NaN   55036.0
#         Baldwin County      24578.0   83544.0      NaN      NaN  203360.0
#         Barbour County       4816.0    5622.0      NaN      NaN   26201.0
#         Bibb County          1986.0    7525.0      NaN      NaN   22580.0
#         Blount County        2640.0   24711.0      NaN      NaN   57667.0
# ...                             ...       ...      ...      ...       ...
# Vermont Orleans County          NaN       NaN      NaN      NaN   26951.0
#         Rutland County          NaN       NaN      NaN      NaN   59676.0
#         Washington County       NaN       NaN      NaN      NaN   58691.0
#         Windham County          NaN       NaN      NaN      NaN   43332.0
#         Windsor County          NaN       NaN      NaN      NaN   55485.0
#
#                                 Men  Hispanic  White  Black  Native  ...  \
# state   county                                                       ...
# Alabama Autauga County     0.488753       2.7   75.4   18.9     0.3  ...
#         Baldwin County     0.489413       4.4   83.1    9.5     0.8  ...
#         Barbour County     0.533415       4.2   45.7   47.8     0.2  ...
#         Bibb County        0.542560       2.4   74.6   22.0     0.4  ...
#         Blount County      0.494043       9.0   87.4    1.5     0.3  ...
# ...                             ...       ...    ...    ...     ...  ...
# Vermont Orleans County     0.502171       1.4   95.5    0.4     0.5  ...
#         Rutland County     0.490566       1.4   95.5    0.7     0.3  ...
#         Washington County  0.494062       1.9   94.4    0.8     0.3  ...
#         Windham County     0.488600       2.2   93.5    0.8     0.1  ...
#         Windsor County     0.489700       1.5   95.0    0.7     0.2  ...
#
#                            Walk  OtherTransp  WorkAtHome  MeanCommute  \
# state   county
# Alabama Autauga County      0.6          1.3         2.5         25.8
#         Baldwin County      0.8          1.1         5.6         27.0
#         Barbour County      2.2          1.7         1.3         23.4
#         Bibb County         0.3          1.7         1.5         30.0
#         Blount County       0.4          0.4         2.1         35.0
# ...                         ...          ...         ...          ...
# Vermont Orleans County      3.0          1.3         7.9         24.2
#         Rutland County      5.1          0.9         5.2         21.1
#         Washington County   6.1          1.4         7.2         22.9
#         Windham County      5.4          1.9        12.1         21.3
#         Windsor County      4.2          0.8         5.3         22.8
#
#                            Employed  PrivateWork  PublicWork  SelfEmployed  \
# state   county
# Alabama Autauga County     0.438113         74.1        20.2           5.6
#         Baldwin County     0.440239         80.7        12.9           6.3
#         Barbour County     0.338842         74.1        19.1           6.5
#         Bibb County        0.361869         76.0        17.4           6.3
#         Blount County      0.370749         83.9        11.9           4.0
# ...                             ...          ...         ...           ...
# Vermont Orleans County     0.453675         70.9        16.1          12.0
#         Rutland County     0.505262         77.6        13.8           8.4
#         Washington County  0.540168         73.6        17.4           8.9
#         Windham County     0.504985         74.7        12.9          12.2
#         Windsor County     0.506425         78.8        12.8           8.1
#
#                            FamilyWork  Unemployment
# state   county
# Alabama Autauga County            0.1           5.2
#         Baldwin County            0.1           5.5
#         Barbour County            0.3          12.4
#         Bibb County               0.3           8.2
#         Blount County             0.1           4.9
# ...                               ...           ...
# Vermont Orleans County            1.0           4.4
#         Rutland County            0.2           4.7
#         Washington County         0.1           3.9
#         Windham County            0.2           5.6
#         Windsor County            0.3           4.5
#
# [4731 rows x 34 columns]

# %%
fig = plt.figure(figsize=(5, 12))
sns.heatmap(df.corr()[['Pres_DEM', 'Pres_REP']], annot=True)
plt.show()

# %% [markdown]
# $\begin{aligned}
# \rightarrow &\textbf{Pres_DEM과 Pres_REP의 Correlation이 높다는 것은 데이터처리가 덜 됐음을 의미} \\
#             &\text{Pres_DEM과 Pres_REP를 인구수가 아닌 비율로 변환할 필요가 있음}
# \end{aligned}$

# %%
df_norm = df.copy()

# %%
df_norm['Pres_DEM'] /= df['Pres_DEM'] + df['Pres_REP']
df_norm['Pres_REP'] /= df['Pres_DEM'] + df['Pres_REP']
df_norm['Gov_DEM'] /= df['Gov_DEM'] + df['Gov_REP']
df_norm['Gov_REP'] /= df['Gov_DEM'] + df['Gov_REP']

# %%
fig = plt.figure(figsize=(5, 12))
sns.heatmap(df_norm.corr()[['Pres_DEM', 'Pres_REP']], annot=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import numpy as np

class SeabornFig2Grid():

    def __init__(self, seaborngrid, fig,  subplot_spec):
        self.fig = fig
        self.sg = seaborngrid
        self.subplot = subplot_spec
        if isinstance(self.sg, sns.axisgrid.FacetGrid) or \
            isinstance(self.sg, sns.axisgrid.PairGrid):
            self._movegrid()
        elif isinstance(self.sg, sns.axisgrid.JointGrid):
            self._movejointgrid()
        self._finalize()

    def _movegrid(self):
        """ Move PairGrid or Facetgrid """
        self._resize()
        n = self.sg.axes.shape[0]
        m = self.sg.axes.shape[1]
        self.subgrid = gridspec.GridSpecFromSubplotSpec(n,m, subplot_spec=self.subplot)
        for i in range(n):
            for j in range(m):
                self._moveaxes(self.sg.axes[i,j], self.subgrid[i,j])

    def _movejointgrid(self):
        """ Move Jointgrid """
        h= self.sg.ax_joint.get_position().height
        h2= self.sg.ax_marg_x.get_position().height
        r = int(np.round(h/h2))
        self._resize()
        self.subgrid = gridspec.GridSpecFromSubplotSpec(r+1,r+1, subplot_spec=self.subplot)

        self._moveaxes(self.sg.ax_joint, self.subgrid[1:, :-1])
        self._moveaxes(self.sg.ax_marg_x, self.subgrid[0, :-1])
        self._moveaxes(self.sg.ax_marg_y, self.subgrid[1:, -1])

    def _moveaxes(self, ax, gs):
        #https://stackoverflow.com/a/46906599/4124317
        ax.remove()
        ax.figure=self.fig
        self.fig.axes.append(ax)
        self.fig.add_axes(ax)
        ax._subplotspec = gs
        ax.set_position(gs.get_position(self.fig))
        ax.set_subplotspec(gs)

    def _finalize(self):
        plt.close(self.sg.fig)
        self.fig.canvas.mpl_connect("resize_event", self._resize)
        self.fig.canvas.draw()

    def _resize(self, evt=None):
        self.sg.fig.set_size_inches(self.fig.get_size_inches())

# %%
g0 = sns.jointplot(x='White', y='Pres_REP', data=df_norm, 
                   kind='hex',
                   #alpha=0.3,
                  )
g1 = sns.jointplot(x='White', y='Pres_REP', hue='Professional', data=df_norm, alpha=0.2)
g2 = sns.jointplot(x='Black', y='Pres_DEM', data=df_norm, 
                   #kind='hex',
                   alpha=0.2,
                  )
g3 = sns.jointplot(x='Black', y='Pres_DEM', hue='Professional', data=df_norm, alpha=0.2)

fig = plt.figure(figsize=(15, 15))
gs = gridspec.GridSpec(2, 2)
mg0 = SeabornFig2Grid(g0, fig, gs[0])
mg1 = SeabornFig2Grid(g1, fig, gs[1])
mg2 = SeabornFig2Grid(g2, fig, gs[2])
mg3 = SeabornFig2Grid(g3, fig, gs[3])

gs.tight_layout(fig)

# %% [markdown]
#  [Reference..](https://plotly.com/python/county-choropleth/#the-entire-usa)

# %%
state_code1.head()
# Out:
#   State Name/District Postal Abbreviation Postal Code
# 0             Alabama                Ala.          AL
# 1              Alaska              Alaska          AK
# 2             Arizona               Ariz.          AZ
# 3            Arkansas                Ark.          AR
# 4          California              Calif.          CA

# %%
state_map = state_code1.set_index('State Name/District')['Postal Code']

# %%
state_map.head()
# Out:
# State Name/District
# Alabama       AL
# Alaska        AK
# Arizona       AZ
# Arkansas      AR
# California    CA
# Name: Postal Code, dtype: object

# %%
 df_norm.head(-10)
# Out:
#                                 Pres_DEM  Pres_REP  Gov_DEM  Gov_REP  \
# state        county
# Alabama      Autauga County     0.274423  0.725577      NaN      NaN
#              Baldwin County     0.227317  0.772683      NaN      NaN
#              Barbour County     0.461391  0.538609      NaN      NaN
#              Bibb County        0.208811  0.791189      NaN      NaN
#              Blount County      0.096523  0.903477      NaN      NaN
# ...                                  ...       ...      ...      ...
# Rhode Island Washington County       NaN       NaN      NaN      NaN
# Vermont      Addison County          NaN       NaN      NaN      NaN
#              Bennington County       NaN       NaN      NaN      NaN
#              Caledonia County        NaN       NaN      NaN      NaN
#              Chittenden County       NaN       NaN      NaN      NaN
#
#                                 TotalPop       Men  Hispanic  White  Black  \
# state        county
# Alabama      Autauga County      55036.0  0.488753       2.7   75.4   18.9
#              Baldwin County     203360.0  0.489413       4.4   83.1    9.5
#              Barbour County      26201.0  0.533415       4.2   45.7   47.8
#              Bibb County         22580.0  0.542560       2.4   74.6   22.0
#              Blount County       57667.0  0.494043       9.0   87.4    1.5
# ...                                  ...       ...       ...    ...    ...
# Rhode Island Washington County  126190.0  0.484618       3.0   91.3    1.3
# Vermont      Addison County      36825.0  0.494610       2.2   93.0    0.9
#              Bennington County   36054.0  0.490625       1.8   94.7    0.8
#              Caledonia County    30576.0  0.502551       1.5   95.1    0.9
#              Chittenden County  160985.0  0.490282       2.2   89.2    2.5
#
#                                 Native  ...  Walk  OtherTransp  WorkAtHome  \
# state        county                     ...
# Alabama      Autauga County        0.3  ...   0.6          1.3         2.5
#              Baldwin County        0.8  ...   0.8          1.1         5.6
#              Barbour County        0.2  ...   2.2          1.7         1.3
#              Bibb County           0.4  ...   0.3          1.7         1.5
#              Blount County         0.3  ...   0.4          0.4         2.1
# ...                                ...  ...   ...          ...         ...
# Rhode Island Washington County     0.8  ...   2.7          0.9         4.9
# Vermont      Addison County        0.3  ...   7.6          1.2         9.4
#              Bennington County     0.1  ...   4.9          2.0         8.0
#              Caledonia County      0.2  ...   3.8          1.2         7.8
#              Chittenden County     0.2  ...   7.8          2.8         5.4
#
#                                 MeanCommute  Employed  PrivateWork  \
# state        county
# Alabama      Autauga County            25.8  0.438113         74.1
#              Baldwin County            27.0  0.440239         80.7
#              Barbour County            23.4  0.338842         74.1
#              Bibb County               30.0  0.361869         76.0
#              Blount County             35.0  0.370749         83.9
# ...                                     ...       ...          ...
# Rhode Island Washington County         25.9  0.511736         75.7
# Vermont      Addison County            23.8  0.539633         77.9
#              Bennington County         19.3  0.488295         77.6
#              Caledonia County          26.0  0.473411         74.2
#              Chittenden County         21.1  0.559394         80.0
#
#                                 PublicWork  SelfEmployed  FamilyWork  \
# state        county
# Alabama      Autauga County           20.2           5.6         0.1
#              Baldwin County           12.9           6.3         0.1
#              Barbour County           19.1           6.5         0.3
#              Bibb County              17.4           6.3         0.3
#              Blount County            11.9           4.0         0.1
# ...                                    ...           ...         ...
# Rhode Island Washington County        17.3           6.9         0.1
# Vermont      Addison County           10.3          11.5         0.3
#              Bennington County        10.8          11.4         0.2
#              Caledonia County         13.8          10.9         1.1
#              Chittenden County        14.3           5.6         0.1
#
#                                 Unemployment
# state        county
# Alabama      Autauga County              5.2
#              Baldwin County              5.5
#              Barbour County             12.4
#              Bibb County                 8.2
#              Blount County               4.9
# ...                                      ...
# Rhode Island Washington County           6.0
# Vermont      Addison County              4.4
#              Bennington County           4.4
#              Caledonia County            4.9
#              Chittenden County           4.1
#
# [4721 rows x 34 columns]

# %%
df_norm.reset_index()['county']
# Out:
# 0          Autauga County
# 1          Baldwin County
# 2          Barbour County
# 3             Bibb County
# 4           Blount County
#               ...
# 4726       Orleans County
# 4727       Rutland County
# 4728    Washington County
# 4729       Windham County
# 4730       Windsor County
# Name: county, Length: 4731, dtype: object

# %%
counties = df_norm.reset_index()['county'] + ', ' + df_norm.reset_index()['state'].map(state_map)

# %% [markdown]
# ...

# %%
df_norm
# Out:
#                            Pres_DEM  Pres_REP  Gov_DEM  Gov_REP  TotalPop  \
# state   county
# Alabama Autauga County     0.274423  0.725577      NaN      NaN   55036.0
#         Baldwin County     0.227317  0.772683      NaN      NaN  203360.0
#         Barbour County     0.461391  0.538609      NaN      NaN   26201.0
#         Bibb County        0.208811  0.791189      NaN      NaN   22580.0
#         Blount County      0.096523  0.903477      NaN      NaN   57667.0
# ...                             ...       ...      ...      ...       ...
# Vermont Orleans County          NaN       NaN      NaN      NaN   26951.0
#         Rutland County          NaN       NaN      NaN      NaN   59676.0
#         Washington County       NaN       NaN      NaN      NaN   58691.0
#         Windham County          NaN       NaN      NaN      NaN   43332.0
#         Windsor County          NaN       NaN      NaN      NaN   55485.0
#
#                                 Men  Hispanic  White  Black  Native  ...  \
# state   county                                                       ...
# Alabama Autauga County     0.488753       2.7   75.4   18.9     0.3  ...
#         Baldwin County     0.489413       4.4   83.1    9.5     0.8  ...
#         Barbour County     0.533415       4.2   45.7   47.8     0.2  ...
#         Bibb County        0.542560       2.4   74.6   22.0     0.4  ...
#         Blount County      0.494043       9.0   87.4    1.5     0.3  ...
# ...                             ...       ...    ...    ...     ...  ...
# Vermont Orleans County     0.502171       1.4   95.5    0.4     0.5  ...
#         Rutland County     0.490566       1.4   95.5    0.7     0.3  ...
#         Washington County  0.494062       1.9   94.4    0.8     0.3  ...
#         Windham County     0.488600       2.2   93.5    0.8     0.1  ...
#         Windsor County     0.489700       1.5   95.0    0.7     0.2  ...
#
#                            Walk  OtherTransp  WorkAtHome  MeanCommute  \
# state   county
# Alabama Autauga County      0.6          1.3         2.5         25.8
#         Baldwin County      0.8          1.1         5.6         27.0
#         Barbour County      2.2          1.7         1.3         23.4
#         Bibb County         0.3          1.7         1.5         30.0
#         Blount County       0.4          0.4         2.1         35.0
# ...                         ...          ...         ...          ...
# Vermont Orleans County      3.0          1.3         7.9         24.2
#         Rutland County      5.1          0.9         5.2         21.1
#         Washington County   6.1          1.4         7.2         22.9
#         Windham County      5.4          1.9        12.1         21.3
#         Windsor County      4.2          0.8         5.3         22.8
#
#                            Employed  PrivateWork  PublicWork  SelfEmployed  \
# state   county
# Alabama Autauga County     0.438113         74.1        20.2           5.6
#         Baldwin County     0.440239         80.7        12.9           6.3
#         Barbour County     0.338842         74.1        19.1           6.5
#         Bibb County        0.361869         76.0        17.4           6.3
#         Blount County      0.370749         83.9        11.9           4.0
# ...                             ...          ...         ...           ...
# Vermont Orleans County     0.453675         70.9        16.1          12.0
#         Rutland County     0.505262         77.6        13.8           8.4
#         Washington County  0.540168         73.6        17.4           8.9
#         Windham County     0.504985         74.7        12.9          12.2
#         Windsor County     0.506425         78.8        12.8           8.1
#
#                            FamilyWork  Unemployment
# state   county
# Alabama Autauga County            0.1           5.2
#         Baldwin County            0.1           5.5
#         Barbour County            0.3          12.4
#         Bibb County               0.3           8.2
#         Blount County             0.1           4.9
# ...                               ...           ...
# Vermont Orleans County            1.0           4.4
#         Rutland County            0.2           4.7
#         Washington County         0.1           3.9
#         Windham County            0.2           5.6
#         Windsor County            0.3           4.5
#
# [4731 rows x 34 columns]

# %%
df_norm.to_csv('./DataFrame_norm.csv')
